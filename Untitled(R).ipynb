# %% [markdown]
# # Results.....

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import root_mean_squared_error, r2_score, mean_absolute_percentage_error
import scienceplots
plt.style.use(["science","nature"])
plt.rcParams.update({"font.size": 12,
                    "xtick.labelsize": 12,
                    "ytick.labelsize": 12,
                    "axes.labelsize": 12,
                    'legend.fontsize': 12})
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore")
rs=142
tsize=.35

# %%
var="R"
#data = pd.read_csv("datas/dataforR_all.csv",index_col=0)
data = pd.read_csv("datas/dataforR_all.csv",index_col=0)
#data = pd.read_csv("datas/dataforR_all.csv",index_col=0)
data=data[data.index>="1996-08"] # Only cycl2 24 and 25
data=data.rename(columns={"R (Sunspot)":"R",
                          "f10.7_index":"F10.7",
                          "Dst-index":"Dst",
                          "Scalar B, nT":"B |IMF|",
                          "SW Plasma Temperature, K":"sw Temperature",
                          "SW Proton Density, N/cm^3":"sw Density",
                          "SW Plasma Speed, km/s":"sw Speed",
                          "Alpha/Prot. ratio":"Alpha/Proton ratio"})
print(len(data))
data=data[(data[var]>0)&(data[var]<300)]
print(len(data))
# Out:
# 10289
# 8472

# %%
#from sklearn.preprocessing import StandardScaler, QuantileTransformer
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import mean_squared_error, r2_score
# ─────────────────────────────────────────────
# 1. Pre-procesamiento
# ─────────────────────────────────────────────
#X = data.drop(columns=[var]).values
#y = data[var].values.reshape(-1, 1)

#sc_x, sc_y = StandardScaler(), StandardScaler()
#X_std = sc_x.fit_transform(X).astype(np.float32)
#y_std = sc_y.fit_transform(y).astype(np.float32)
#sc_x, sc_y = QuantileTransformer(random_state=rs), QuantileTransformer(random_state=rs)
#X_std = sc_x.fit_transform(X).astype(np.float32)
#y_std = sc_y.fit_transform(y).astype(np.float32)

#X_tr, X_te, y_tr, y_te = train_test_split(X_std, 
#                                          y_std, 
#                                          test_size=tsize, 
#                                          random_state=rs)

# %%
#pd.DataFrame(y_tr).describe()[0].values

# %%
#pd.DataFrame({"Full original":pd.DataFrame(y).describe()[0].values,
#             "Test scaled":pd.DataFrame(y_te).describe()[0].values,
#             "Train scaled":pd.DataFrame(y_tr).describe()[0].values},
#             index=pd.DataFrame(y_tr).describe().index)

# %%
#plt.figure(figsize=(16,4))
#plt.subplot(131)
#plt.hist(y,bins=50,label="Original"); plt.legend()
#plt.subplot(132)
#plt.hist(y_std,bins=50,label="Transform"); plt.legend()
#plt.subplot(133)
#plt.plot(y_std,label="Time series"); plt.legend()
#plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(16,5))
sns.heatmap(data.corr(), annot=True, cmap="jet")
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['Shannon Entropy', 'Sample Entropy', 'Permutation Entropy',
#        'Spectral Entropy', 'Approximate Entropy', 'Higuchi Fractal Dim.',
#        'Katz Fractal Dim.', 'Petrosian Fractal Dim.', 'Lempel-Ziv Complexity',
#        'Hurst Exponent', 'R', 'B |IMF|', 'sw Temperature', 'sw Density',
#        'sw Speed', 'Alpha/Proton ratio'],
#       dtype='object')

# %%
#data=data.drop(columns=['Sample Entropy','Permutation Entropy',"Approximate Entropy","Petrosian Fractal Dim."])

# %%
from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
# ─────────────────────────────────────────────
# 1. Pre-procesamiento
# ─────────────────────────────────────────────
X = data.drop(columns=[var]).values
y = data[var].values.reshape(-1, 1)

#sc_x, sc_y = StandardScaler(), StandardScaler()
#X_std = sc_x.fit_transform(X).astype(np.float32)
#y_std = sc_y.fit_transform(y).astype(np.float32)
sc_x, sc_y = QuantileTransformer(random_state=rs), QuantileTransformer(random_state=rs)
X_std = sc_x.fit_transform(X).astype(np.float32)
y_std = sc_y.fit_transform(y).astype(np.float32)

X_tr, X_te, y_tr, y_te = train_test_split(X_std, 
                                          y_std, 
                                          test_size=tsize, 
                                          random_state=rs)

# %%
pd.DataFrame({"Full original":pd.DataFrame(y).describe()[0].values,
             "Test scaled":pd.DataFrame(y_te).describe()[0].values,
             "Train scaled":pd.DataFrame(y_tr).describe()[0].values},
             index=pd.DataFrame(y_tr).describe().index)
# Out:
#        Full original  Test scaled  Train scaled
# count    8472.000000  2966.000000   5506.000000
# mean       82.399551     0.497263      0.501427
# std        60.795228     0.291035      0.287493
# min         1.000000     0.000000      0.001001
# 25%        30.000000     0.247247      0.256256
# 50%        69.000000     0.493493      0.503003
# 75%       123.000000     0.747247      0.751251
# max       295.000000     0.999777      1.000000

# %% [markdown]
# # 1 | Multiple Layer Perceptron - GPU

# %%
# ================================================================
#  MLP con PyTorch + Optuna para búsqueda de hiper-parámetros
#  Dataset: 4 602 × 14   ‒ Target: R
#  CUDA se usa si está disponible (MX250)
#  Requiere: pip install optuna torch torchvision scikit-learn
# ================================================================
import numpy as np, torch, torch.nn as nn, optuna, joblib
from torch.utils.data import TensorDataset, DataLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ─────────────────────────────────────────────
# 2. Definición del modelo
# ─────────────────────────────────────────────
class MLP(nn.Module):
    def __init__(self, in_dim: int,
                 h1: int, h2: int | None, h3: int | None,
                 p_drop: float = 0.2):
        """Hasta 3 capas ocultas; las que tengan None se omiten."""
        super().__init__()
        layers = [nn.Linear(in_dim, h1), nn.ReLU(), nn.Dropout(p_drop)]
        if h2:
            layers += [nn.Linear(h1, h2), nn.ReLU(), nn.Dropout(p_drop)]
            prev = h2
        else:
            prev = h1
        if h3:
            layers += [nn.Linear(prev, h3), nn.ReLU(), nn.Dropout(p_drop)]
            prev = h3
        layers += [nn.Linear(prev, 1)]
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)

# ─────────────────────────────────────────────
# 3. Función de entrenamiento con early-stopping
# ─────────────────────────────────────────────
def train_mlp(params, epochs=500, patience=20):
    model = MLP(
        in_dim=X_tr.shape[1],
        h1=params['h1'],
        h2=params.get('h2'),
        h3=params.get('h3'),
        p_drop=params['dropout']).to(device)

    opt = torch.optim.Adam(
        model.parameters(),
        lr=params['lr'],
        weight_decay=params['weight_decay'])

    batch_size = params['batch']
    ds_train   = TensorDataset(torch.from_numpy(X_tr), torch.from_numpy(y_tr))
    dl_train   = DataLoader(ds_train, batch_size=batch_size, shuffle=True)

    best_val, wait = np.inf, 0
    for _ in range(epochs):
        # ── forward/backward ───────────────────────────────────
        model.train()
        for xb, yb in dl_train:
            xb, yb = xb.to(device), yb.to(device)
            opt.zero_grad()
            loss = nn.functional.mse_loss(model(xb), yb)
            loss.backward()
            opt.step()

        # ── validación rápida ─────────────────────────────────
        model.eval()
        with torch.no_grad():
            preds = model(torch.from_numpy(X_te).to(device)).cpu().numpy()
            val_loss = mean_squared_error(y_te, preds)
        # early stop
        if val_loss < best_val - 1e-4:
            best_val = val_loss
            best_state = model.state_dict()
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    model.load_state_dict(best_state)
    return model, best_val

# ─────────────────────────────────────────────
# 4. Objetivo Optuna
# ─────────────────────────────────────────────
def objective(trial: optuna.Trial) -> float:
    # muestreo de hiper-parámetros
    h1 = trial.suggest_int('h1',       32, 128, step=32)
    h2 = trial.suggest_int('h2',       16, 128, step=16)
    use_h3 = trial.suggest_categorical('use_h3', [False, True])
    h3 = trial.suggest_int('h3', 16, 64, step=16) if use_h3 else None

    params = dict(
        h1       = h1,
        h2       = h2,
        h3       = h3,
        dropout  = trial.suggest_float('dropout', 0.0, 0.4, step=0.1),
        lr       = trial.suggest_float('lr', 1e-4, 5e-3, log=True),
        weight_decay = trial.suggest_float('weight_decay', 1e-5, 1e-2, log=True),
        batch    = trial.suggest_categorical('batch', [64, 128, 256]),
    )

    # entrena y evalúa
    _, val_rmse = train_mlp(params)
    # Optuna minimiza -> devolver RMSE
    return val_rmse

# ─────────────────────────────────────────────
# 5. Ejecución del estudio
# ─────────────────────────────────────────────
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=40, timeout=None, show_progress_bar=True)

print("\n⇢  Mejor RMSE válido  :", study.best_value**0.5)   # pasa de MSE a RMSE
print("⇢  Mejores parámetros :", study.best_params)

joblib.dump(study, "optuna_mlp_study.pkl")

# ─────────────────────────────────────────────
# 6. Entrenamiento final con el mejor conjunto
# ─────────────────────────────────────────────
best_model, _ = train_mlp(study.best_params, epochs=800, patience=30)
# Out:
# [I 2025-07-09 08:07:47,134] A new study created in memory with name: no-name-53e424ed-4dad-4167-a95b-c1d4e1fd81b9
# Best trial: 0. Best value: 0.0321263:   2%|▎         | 1/40 [00:04<03:05,  4.76s/it]
# [I 2025-07-09 08:07:51,896] Trial 0 finished with value: 0.032126285135746 and parameters: {'h1': 32, 'h2': 16, 'use_h3': True, 'h3': 64, 'dropout': 0.30000000000000004, 'lr': 0.0044474460126200455, 'weight_decay': 0.0013692430662116603, 'batch': 128}. Best is trial 0 with value: 0.032126285135746.
# Best trial: 1. Best value: 0.0320714:   5%|▌         | 2/40 [00:13<04:38,  7.33s/it]
# [I 2025-07-09 08:08:01,021] Trial 1 finished with value: 0.03207141160964966 and parameters: {'h1': 64, 'h2': 32, 'use_h3': False, 'dropout': 0.0, 'lr': 0.001581079660448751, 'weight_decay': 0.002656951948034246, 'batch': 128}. Best is trial 1 with value: 0.03207141160964966.
# Best trial: 2. Best value: 0.0294372:   8%|▊         | 3/40 [00:38<09:17, 15.07s/it]
# [I 2025-07-09 08:08:25,308] Trial 2 finished with value: 0.029437176883220673 and parameters: {'h1': 96, 'h2': 112, 'use_h3': False, 'dropout': 0.30000000000000004, 'lr': 0.0003189767943109229, 'weight_decay': 1.0174608520097646e-05, 'batch': 128}. Best is trial 2 with value: 0.029437176883220673.
# Best trial: 2. Best value: 0.0294372:  10%|█         | 4/40 [01:07<12:18, 20.51s/it]
# [I 2025-07-09 08:08:54,166] Trial 3 finished with value: 0.031506702303886414 and parameters: {'h1': 32, 'h2': 16, 'use_h3': False, 'dropout': 0.4, 'lr': 0.00017329650313865845, 'weight_decay': 5.79787315152475e-05, 'batch': 128}. Best is trial 2 with value: 0.029437176883220673.
# Best trial: 2. Best value: 0.0294372:  12%|█▎        | 5/40 [01:12<08:53, 15.26s/it]
# [I 2025-07-09 08:09:00,095] Trial 4 finished with value: 0.03523942828178406 and parameters: {'h1': 96, 'h2': 16, 'use_h3': True, 'h3': 32, 'dropout': 0.2, 'lr': 0.00492167716755412, 'weight_decay': 0.009025665689187994, 'batch': 128}. Best is trial 2 with value: 0.029437176883220673.
# Best trial: 2. Best value: 0.0294372:  15%|█▌        | 6/40 [01:22<07:29, 13.21s/it]
# [I 2025-07-09 08:09:09,340] Trial 5 finished with value: 0.029744792729616165 and parameters: {'h1': 128, 'h2': 48, 'use_h3': False, 'dropout': 0.2, 'lr': 0.002551098603969131, 'weight_decay': 0.0002026929662596574, 'batch': 128}. Best is trial 2 with value: 0.029437176883220673.
# Best trial: 2. Best value: 0.0294372:  18%|█▊        | 7/40 [01:25<05:32, 10.08s/it]
# [I 2025-07-09 08:09:12,963] Trial 6 finished with value: 0.033052753657102585 and parameters: {'h1': 32, 'h2': 32, 'use_h3': False, 'dropout': 0.0, 'lr': 0.0027492141956173264, 'weight_decay': 0.004046089760122791, 'batch': 64}. Best is trial 2 with value: 0.029437176883220673.
# Best trial: 2. Best value: 0.0294372:  20%|██        | 8/40 [01:40<06:05, 11.44s/it]
# [I 2025-07-09 08:09:27,310] Trial 7 finished with value: 0.030701493844389915 and parameters: {'h1': 32, 'h2': 48, 'use_h3': True, 'h3': 32, 'dropout': 0.2, 'lr': 0.0017481009824865167, 'weight_decay': 0.00039505603194219625, 'batch': 64}. Best is trial 2 with value: 0.029437176883220673.
# Best trial: 8. Best value: 0.0290424:  22%|██▎       | 9/40 [02:09<08:48, 17.05s/it]
# [I 2025-07-09 08:09:56,717] Trial 8 finished with value: 0.029042383655905724 and parameters: {'h1': 128, 'h2': 80, 'use_h3': True, 'h3': 32, 'dropout': 0.2, 'lr': 0.0001930176063604091, 'weight_decay': 1.8168079801444e-05, 'batch': 64}. Best is trial 8 with value: 0.029042383655905724.
# Best trial: 8. Best value: 0.0290424:  25%|██▌       | 10/40 [02:16<06:55, 13.86s/it]
# [I 2025-07-09 08:10:03,418] Trial 9 finished with value: 0.031529221683740616 and parameters: {'h1': 32, 'h2': 64, 'use_h3': False, 'dropout': 0.4, 'lr': 0.004924677288516811, 'weight_decay': 0.00012419201471900357, 'batch': 128}. Best is trial 8 with value: 0.029042383655905724.
# [I 2025-07-09 08:19:38,842] Trial 31 finished with value: 0.02494793012738228 and parameters: {'h1': 128, 'h2': 80, 'use_h3': True, 'h3': 64, 'dropout': 0.1, 'lr': 0.0006293949049423725, 'weight_decay': 1.9623696829936162e-05, 'batch': 256}. Best is trial 31 with value: 0.02494793012738228.
# Best trial: 31. Best value: 0.0249479:  82%|████████▎ | 33/40 [12:22<02:43, 23.39s/it]
# [I 2025-07-09 08:20:09,514] Trial 32 finished with value: 0.02517561800777912 and parameters: {'h1': 128, 'h2': 64, 'use_h3': True, 'h3': 64, 'dropout': 0.1, 'lr': 0.0007417694799964742, 'weight_decay': 1.6744700867338264e-05, 'batch': 256}. Best is trial 31 with value: 0.02494793012738228.
# Best trial: 31. Best value: 0.0249479:  85%|████████▌ | 34/40 [12:43<02:15, 22.63s/it]
# [I 2025-07-09 08:20:30,367] Trial 33 finished with value: 0.02580617554485798 and parameters: {'h1': 128, 'h2': 80, 'use_h3': True, 'h3': 64, 'dropout': 0.1, 'lr': 0.0006523082600302092, 'weight_decay': 1.590807135477658e-05, 'batch': 256}. Best is trial 31 with value: 0.02494793012738228.
# Best trial: 31. Best value: 0.0249479:  88%|████████▊ | 35/40 [12:59<01:43, 20.70s/it]
# [I 2025-07-09 08:20:46,562] Trial 34 finished with value: 0.02866131067276001 and parameters: {'h1': 128, 'h2': 32, 'use_h3': False, 'dropout': 0.0, 'lr': 0.0004326212482884761, 'weight_decay': 0.00018244980974751936, 'batch': 256}. Best is trial 31 with value: 0.02494793012738228.
# Best trial: 31. Best value: 0.0249479:  90%|█████████ | 36/40 [13:26<01:29, 22.50s/it]
# [I 2025-07-09 08:21:13,253] Trial 35 finished with value: 0.02677905187010765 and parameters: {'h1': 128, 'h2': 64, 'use_h3': True, 'h3': 64, 'dropout': 0.1, 'lr': 0.0002808849257741031, 'weight_decay': 1.3412707498538243e-05, 'batch': 256}. Best is trial 31 with value: 0.02494793012738228.
# Best trial: 31. Best value: 0.0249479:  92%|█████████▎| 37/40 [13:53<01:12, 24.02s/it]
# [I 2025-07-09 08:21:40,834] Trial 36 finished with value: 0.0262445155531168 and parameters: {'h1': 96, 'h2': 80, 'use_h3': False, 'dropout': 0.2, 'lr': 0.0007447563891214505, 'weight_decay': 6.318677466957434e-05, 'batch': 256}. Best is trial 31 with value: 0.02494793012738228.
# Best trial: 31. Best value: 0.0249479:  95%|█████████▌| 38/40 [13:58<00:36, 18.29s/it]
# [I 2025-07-09 08:21:45,757] Trial 37 finished with value: 0.02884519472718239 and parameters: {'h1': 128, 'h2': 48, 'use_h3': True, 'h3': 64, 'dropout': 0.0, 'lr': 0.001427479057710524, 'weight_decay': 1.9066218207720908e-05, 'batch': 256}. Best is trial 31 with value: 0.02494793012738228.
# Best trial: 31. Best value: 0.0249479:  98%|█████████▊| 39/40 [14:08<00:15, 15.74s/it]
# [I 2025-07-09 08:21:55,541] Trial 38 finished with value: 0.0325283482670784 and parameters: {'h1': 96, 'h2': 96, 'use_h3': False, 'dropout': 0.2, 'lr': 0.002215684486135098, 'weight_decay': 0.0033501140050389393, 'batch': 128}. Best is trial 31 with value: 0.02494793012738228.
# Best trial: 31. Best value: 0.0249479: 100%|██████████| 40/40 [14:31<00:00, 21.79s/it]
# [I 2025-07-09 08:22:18,686] Trial 39 finished with value: 0.02721368335187435 and parameters: {'h1': 128, 'h2': 48, 'use_h3': True, 'h3': 64, 'dropout': 0.1, 'lr': 0.00036304744146520334, 'weight_decay': 1.0168543141607892e-05, 'batch': 256}. Best is trial 31 with value: 0.02494793012738228.
#
# ⇢  Mejor RMSE válido  : 0.15794913778613126
# ⇢  Mejores parámetros : {'h1': 128, 'h2': 80, 'use_h3': True, 'h3': 64, 'dropout': 0.1, 'lr': 0.0006293949049423725, 'weight_decay': 1.9623696829936162e-05, 'batch': 256}

# %%
# ── Métricas finales en escala original ──────
with torch.no_grad():
    best_model.eval()
    preds_te_std = best_model(torch.from_numpy(X_te).to(device)).cpu().numpy()
    preds_tr_std = best_model(torch.from_numpy(X_tr).to(device)).cpu().numpy()

y_te_inv  = sc_y.inverse_transform(y_te)
y_tr_inv  = sc_y.inverse_transform(y_tr)
preds_te  = sc_y.inverse_transform(preds_te_std)
preds_tr  = sc_y.inverse_transform(preds_tr_std)

print("R² test :", r2_score(y_te_inv, preds_te))
print("RMSE test:", mean_squared_error(y_te_inv, preds_te, squared=False))
print("R² train:", r2_score(y_tr_inv, preds_tr))
print("RMSE train:", mean_squared_error(y_tr_inv, preds_tr, squared=False))
# Out:
# R² test : 0.6140008568763733
# RMSE test: 38.008343
# R² train: 0.8036043047904968
# RMSE train: 26.8481

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Predictions")
plt.scatter(y_tr_inv,preds_tr,label="Train")
plt.scatter(y_te_inv,preds_te,label="Test")
plt.legend()
plt.subplot(122)
plt.title("Resisuals")
plt.scatter(y_tr_inv,preds_tr-y_tr_inv,label="Train")
plt.scatter(y_te_inv,preds_te-y_te_inv,label="Test")
plt.legend()
plt.show()

# %% [markdown]
# # 3 | XGBoost GPU

# %%
import xgboost as xgb
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
import optuna, numpy as np

dtrain, dtest = xgb.DMatrix(X_tr, label=y_tr), xgb.DMatrix(X_te, label=y_te)

# ── ¿XGBoost tiene GPU? ───────────────────────────────
def xgb_gpu_available() -> bool:
    try:
        # Desde XGB 2.0 existe esto:
        return xgb.core._has_cuda_support()
    except AttributeError:
        # Fallback: intenta una llamada dummy
        try:
            xgb.train({'tree_method':'gpu_hist'}, dtrain, num_boost_round=1, verbose_eval=False)
            return True
        except xgb.core.XGBoostError:
            return False

USE_GPU = xgb_gpu_available()
print("XGBoost GPU disponible?:", USE_GPU)

tree_method = 'gpu_hist' if USE_GPU else 'hist'

# ── Optuna objective ──────────────────────────────────

def objective(trial):
    param = {
        "objective": "reg:squarederror",
        "tree_method": tree_method,          # 'gpu_hist' o 'hist'
        "learning_rate": trial.suggest_float("eta", 0.02, 0.15, log=True),
        "max_depth": trial.suggest_int("max_depth", 1, 4),
        "subsample": trial.suggest_float("subsample", 0.5, 0.9),
        "colsample_bytree": trial.suggest_float("colsample", 0.4, 0.9),
        "lambda": trial.suggest_float("lambda", 1.0, 10.0, log=True),
        "alpha": trial.suggest_float("alpha", 0.0, 1.0),
        "min_child_weight": trial.suggest_float("min_child_weight", 5, 10, log=True),
    }
    n_rounds = trial.suggest_int("n_rounds", 500, 3000, step=500)

    booster = xgb.train(
        param,
        dtrain,
        num_boost_round=n_rounds,
        evals=[(dtest, "val")],
        verbose_eval=False,
        early_stopping_rounds=50,
    )
    preds = booster.predict(dtest)
    return mean_squared_error(y_te, preds)          # Optuna minimiza

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50, show_progress_bar=True, timeout=None)

best_params = study.best_params | {
    "objective": "reg:squarederror",
    "tree_method": tree_method
}
best_rounds = best_params.pop("n_rounds")
booster = xgb.train(best_params, dtrain,
                    num_boost_round=best_rounds,
                    evals=[(dtest, "val")],
                    early_stopping_rounds=50,
                    verbose_eval=False)
# Out:
# [I 2025-07-09 08:22:55,296] A new study created in memory with name: no-name-2019b952-ed00-4ee6-a470-56ad277bbf51
# XGBoost GPU disponible?: False
# Best trial: 0. Best value: 0.0307334:   2%|▏         | 1/50 [00:00<00:18,  2.66it/s]
# [I 2025-07-09 08:22:55,671] Trial 0 finished with value: 0.030733376741409302 and parameters: {'eta': 0.08356768238953992, 'max_depth': 1, 'subsample': 0.6087254828062384, 'colsample': 0.7648178919919921, 'lambda': 2.726707741353999, 'alpha': 0.6556038944702671, 'min_child_weight': 6.432595023371066, 'n_rounds': 1000}. Best is trial 0 with value: 0.030733376741409302.
# Best trial: 1. Best value: 0.0238833:   4%|▍         | 2/50 [00:00<00:17,  2.68it/s]
# [I 2025-07-09 08:22:56,042] Trial 1 finished with value: 0.02388329990208149 and parameters: {'eta': 0.05557980870152836, 'max_depth': 4, 'subsample': 0.8731927315173764, 'colsample': 0.5513540195829643, 'lambda': 1.3712012104221059, 'alpha': 0.928562934721593, 'min_child_weight': 5.578129621078409, 'n_rounds': 500}. Best is trial 1 with value: 0.02388329990208149.
# Best trial: 1. Best value: 0.0238833:   6%|▌         | 3/50 [00:01<00:20,  2.31it/s]
# [I 2025-07-09 08:22:56,548] Trial 2 finished with value: 0.028928343206644058 and parameters: {'eta': 0.022800785152063494, 'max_depth': 2, 'subsample': 0.8660516952195458, 'colsample': 0.8941175107852464, 'lambda': 1.7452325370829753, 'alpha': 0.9099195898613069, 'min_child_weight': 9.040116917942434, 'n_rounds': 1000}. Best is trial 1 with value: 0.02388329990208149.
# Best trial: 1. Best value: 0.0238833:   8%|▊         | 4/50 [00:01<00:19,  2.34it/s]
# [I 2025-07-09 08:22:56,964] Trial 3 finished with value: 0.029186854138970375 and parameters: {'eta': 0.0200317876553511, 'max_depth': 2, 'subsample': 0.7679281828902745, 'colsample': 0.524984059349299, 'lambda': 2.346157171765284, 'alpha': 0.1940643742746362, 'min_child_weight': 8.390538270040091, 'n_rounds': 1000}. Best is trial 1 with value: 0.02388329990208149.
# Best trial: 1. Best value: 0.0238833:  10%|█         | 5/50 [00:02<00:26,  1.72it/s]
# Best trial: 34. Best value: 0.0209876:  74%|███████▍  | 37/50 [00:32<00:09,  1.34it/s]
# [I 2025-07-09 08:23:27,501] Trial 36 finished with value: 0.021926527842879295 and parameters: {'eta': 0.09609983901500375, 'max_depth': 4, 'subsample': 0.8576633894453085, 'colsample': 0.8193646789064765, 'lambda': 1.8735774302287593, 'alpha': 0.4873732802536293, 'min_child_weight': 8.626381687291405, 'n_rounds': 500}. Best is trial 34 with value: 0.02098763734102249.
# Best trial: 34. Best value: 0.0209876:  76%|███████▌  | 38/50 [00:32<00:07,  1.51it/s]
# [I 2025-07-09 08:23:27,967] Trial 37 finished with value: 0.027158206328749657 and parameters: {'eta': 0.06785742001416492, 'max_depth': 2, 'subsample': 0.7953695215821134, 'colsample': 0.7730470826750554, 'lambda': 6.741412812149311, 'alpha': 0.418307466035898, 'min_child_weight': 9.49441069541589, 'n_rounds': 1000}. Best is trial 34 with value: 0.02098763734102249.
# Best trial: 34. Best value: 0.0209876:  78%|███████▊  | 39/50 [00:33<00:07,  1.49it/s]
# [I 2025-07-09 08:23:28,660] Trial 38 finished with value: 0.023640677332878113 and parameters: {'eta': 0.08181233397863975, 'max_depth': 3, 'subsample': 0.8474289356737322, 'colsample': 0.897254668517246, 'lambda': 4.750620240920268, 'alpha': 0.23295907096469615, 'min_child_weight': 8.078815805058278, 'n_rounds': 1000}. Best is trial 34 with value: 0.02098763734102249.
# Best trial: 34. Best value: 0.0209876:  80%|████████  | 40/50 [00:33<00:06,  1.58it/s]
# [I 2025-07-09 08:23:29,193] Trial 39 finished with value: 0.02264012210071087 and parameters: {'eta': 0.08136506440388519, 'max_depth': 4, 'subsample': 0.8750993071357661, 'colsample': 0.8411458032061331, 'lambda': 6.3141315548081955, 'alpha': 0.5054456373165033, 'min_child_weight': 8.863833057555434, 'n_rounds': 500}. Best is trial 34 with value: 0.02098763734102249.
# Best trial: 34. Best value: 0.0209876:  82%|████████▏ | 41/50 [00:34<00:05,  1.55it/s]
# [I 2025-07-09 08:23:29,875] Trial 40 finished with value: 0.023930491879582405 and parameters: {'eta': 0.09752624267942826, 'max_depth': 3, 'subsample': 0.7941332307336917, 'colsample': 0.7264377142853429, 'lambda': 8.575630660201998, 'alpha': 0.4027933818813699, 'min_child_weight': 9.311791285553785, 'n_rounds': 1000}. Best is trial 34 with value: 0.02098763734102249.
# Best trial: 34. Best value: 0.0209876:  84%|████████▍ | 42/50 [00:35<00:05,  1.35it/s]
# [I 2025-07-09 08:23:30,830] Trial 41 finished with value: 0.021410031244158745 and parameters: {'eta': 0.08771952685497582, 'max_depth': 4, 'subsample': 0.8752079841545708, 'colsample': 0.8655443023016459, 'lambda': 8.854497457308584, 'alpha': 0.9991909045360872, 'min_child_weight': 7.728037145401924, 'n_rounds': 1000}. Best is trial 34 with value: 0.02098763734102249.
# Best trial: 34. Best value: 0.0209876:  86%|████████▌ | 43/50 [00:36<00:05,  1.25it/s]
# [I 2025-07-09 08:23:31,780] Trial 42 finished with value: 0.021719060838222504 and parameters: {'eta': 0.06502034679948436, 'max_depth': 4, 'subsample': 0.8335627203712068, 'colsample': 0.8633502974751419, 'lambda': 7.682482635480724, 'alpha': 0.450337060383517, 'min_child_weight': 8.376603498180515, 'n_rounds': 1000}. Best is trial 34 with value: 0.02098763734102249.
# Best trial: 43. Best value: 0.020826:  88%|████████▊ | 44/50 [00:38<00:06,  1.11s/it]
# [I 2025-07-09 08:23:33,621] Trial 43 finished with value: 0.020825998857617378 and parameters: {'eta': 0.056204720577322356, 'max_depth': 4, 'subsample': 0.879186366408216, 'colsample': 0.8074998734923771, 'lambda': 9.831765416701742, 'alpha': 0.3672981163031436, 'min_child_weight': 7.720322904969133, 'n_rounds': 2000}. Best is trial 43 with value: 0.020825998857617378.
# Best trial: 43. Best value: 0.020826:  90%|█████████ | 45/50 [00:40<00:06,  1.31s/it]
# [I 2025-07-09 08:23:35,405] Trial 44 finished with value: 0.02114800736308098 and parameters: {'eta': 0.049361703678106036, 'max_depth': 4, 'subsample': 0.8825849680622351, 'colsample': 0.8036984836818396, 'lambda': 9.662387314954646, 'alpha': 0.5751315475271416, 'min_child_weight': 8.044148752873872, 'n_rounds': 2000}. Best is trial 43 with value: 0.020825998857617378.
# Best trial: 43. Best value: 0.020826:  92%|█████████▏| 46/50 [00:41<00:05,  1.43s/it]
# [I 2025-07-09 08:23:37,097] Trial 45 finished with value: 0.021047906950116158 and parameters: {'eta': 0.05220155254226895, 'max_depth': 4, 'subsample': 0.8860229054507229, 'colsample': 0.8039307125987756, 'lambda': 9.986499148988075, 'alpha': 0.5718720291457663, 'min_child_weight': 7.448698956611002, 'n_rounds': 2000}. Best is trial 43 with value: 0.020825998857617378.
# Best trial: 43. Best value: 0.020826:  94%|█████████▍| 47/50 [00:43<00:04,  1.42s/it]
# [I 2025-07-09 08:23:38,511] Trial 46 finished with value: 0.02230607531964779 and parameters: {'eta': 0.027494043264431296, 'max_depth': 4, 'subsample': 0.8463955963348556, 'colsample': 0.7489160662935798, 'lambda': 1.0961736732235439, 'alpha': 0.6925237605732933, 'min_child_weight': 7.49790909673107, 'n_rounds': 1500}. Best is trial 43 with value: 0.020825998857617378.
# Best trial: 43. Best value: 0.020826:  96%|█████████▌| 48/50 [00:43<00:02,  1.15s/it]
# [I 2025-07-09 08:23:39,037] Trial 47 finished with value: 0.0308232381939888 and parameters: {'eta': 0.057509953810928424, 'max_depth': 1, 'subsample': 0.8866428749743976, 'colsample': 0.7925769341973931, 'lambda': 1.9146212444029902, 'alpha': 0.5396588193484048, 'min_child_weight': 6.644556343243729, 'n_rounds': 2000}. Best is trial 43 with value: 0.020825998857617378.
# Best trial: 43. Best value: 0.020826:  98%|█████████▊| 49/50 [00:44<00:01,  1.18s/it]
# [I 2025-07-09 08:23:40,282] Trial 48 finished with value: 0.02140689454972744 and parameters: {'eta': 0.05106334806295763, 'max_depth': 4, 'subsample': 0.8172826937019501, 'colsample': 0.8337719834405525, 'lambda': 9.11481524991985, 'alpha': 0.4712095848500707, 'min_child_weight': 6.786931696171274, 'n_rounds': 1500}. Best is trial 43 with value: 0.020825998857617378.
# Best trial: 43. Best value: 0.020826: 100%|██████████| 50/50 [00:46<00:00,  1.08it/s]
# [I 2025-07-09 08:23:41,477] Trial 49 finished with value: 0.024067357182502747 and parameters: {'eta': 0.03535995273626634, 'max_depth': 3, 'subsample': 0.8656428668769758, 'colsample': 0.7562187524012149, 'lambda': 1.3862944053924182, 'alpha': 0.8130504485701806, 'min_child_weight': 7.134616047968081, 'n_rounds': 2000}. Best is trial 43 with value: 0.020825998857617378.

# %%
preds_te_std2 = booster.predict(dtest)
preds_tr_std2 = booster.predict(dtrain)

y_te_inv2  = sc_y.inverse_transform(y_te)
y_tr_inv2  = sc_y.inverse_transform(y_tr)
preds_te2  = sc_y.inverse_transform(np.array(preds_te_std2).reshape(-1, 1))
preds_tr2  = sc_y.inverse_transform(np.array(preds_tr_std2).reshape(-1, 1))

print("R² test :", r2_score(y_te_inv2, preds_te2))
print("RMSE test:", mean_squared_error(y_te_inv2, preds_te2, squared=False))
print("R² train:", r2_score(y_tr_inv2, preds_tr2))
print("RMSE train:", mean_squared_error(y_tr_inv2, preds_tr2, squared=False))
# Out:
# R² test : 0.6719633340835571
# RMSE test: 35.03862
# R² train: 0.9215031266212463
# RMSE train: 16.973589

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Predictions")
plt.scatter(y_tr_inv2,preds_tr2,label="Train")
plt.scatter(y_te_inv2,preds_te2,label="Test")
plt.legend()
plt.subplot(122)
plt.title("Resisuals")
plt.scatter(y_tr_inv2,preds_tr2-y_tr_inv2,label="Train")
plt.scatter(y_te_inv2,preds_te2-y_te_inv2,label="Test")
plt.legend()
plt.show()

# %%
booster

# %%
import numpy as np, matplotlib.pyplot as plt, xgboost as xgb, torch
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from typing import Any

# ═══════════════════════════════════════════════════════════════════
# 1. Wrappers: dan predict() y un fit() vacío (requisito sklearn)
# ═══════════════════════════════════════════════════════════════════
class TorchRegressorWrapper:
    def __init__(self, model: torch.nn.Module, scaler_y):
        self.model = model.eval().to(next(model.parameters()).device)
        self.scaler_y = scaler_y
    def fit(self, X: Any, y: Any):     # <- para que sklearn no proteste
        return self
    def predict(self, X):
        X_t = torch.tensor(X, dtype=torch.float32, device=next(self.model.parameters()).device)
        with torch.no_grad():
            y_hat_std = self.model(X_t).cpu().numpy()
        return self.scaler_y.inverse_transform(y_hat_std).ravel()

class XGBRegressorWrapper:
    def __init__(self, booster: xgb.Booster):
        self.bst = booster
    def fit(self, X: Any, y: Any):
        return self
    def predict(self, X):
        return self.bst.predict(xgb.DMatrix(X))

mlp_wrap = TorchRegressorWrapper(best_model, sc_y)
xgb_wrap = XGBRegressorWrapper(booster)

# ═══════════════════════════════════════════════════════════════════
# 2. Conjuntos para permutar
#    · MLP → entradas estandarizadas
#    · XGB → sin escalar
# ═══════════════════════════════════════════════════════════════════
X_te_std = sc_x.transform(X_te)        # estándar usado en entrenamiento MLP

# ═══════════════════════════════════════════════════════════════════
# 3. Permutation Feature Importance
# ═══════════════════════════════════════════════════════════════════
def pfi(estimator, X, y):
    return permutation_importance(
        estimator, X, y,
        n_repeats=50,
        scoring="neg_root_mean_squared_error",
        random_state=rs,
        n_jobs=-1)

pi_mlp = pfi(mlp_wrap, X_te, y_te)
pi_xgb = pfi(xgb_wrap, X_te, y_te)

# %%
feat_names = data.drop(columns=[var]).columns
len(feat_names)
# Out:
# 15

# %%
sumi=pd.DataFrame({"Features":feat_names,
                   "Importances Mean (MLP)":pi_mlp.importances_mean, 
                   "Importances Std (MLP)":pi_mlp.importances_std,
                  "Importances Mean (XB)":pi_xgb.importances_mean, 
                   "Importances Std (XB)":pi_xgb.importances_std})

# %%
# ═══════════════════════════════════════════════════════════════════
# 4. Plot boxplots lado a lado
# ═══════════════════════════════════════════════════════════════════
def plot_box(ax, result, title):
    order = np.argsort(result.importances_mean)[::-1]
    ax.boxplot(result.importances.T[:, order], vert=False,
               labels=feat_names[order])
    ax.axvline(0, color="k", ls="--")
    ax.set_title(title)
    ax.set_xlabel("Decrease in RMSE (perm−base)")

fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharex=False, sharey=False)
plot_box(axes[0], pi_mlp, "Permutation Importance – MLP")
plot_box(axes[1], pi_xgb, "Permutation Importance – XGBoost")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Permutation Importance – MLP")
plt.boxplot(pi_mlp.importances.T[:, np.argsort(pi_mlp.importances_mean)[::-1]]*1, vert=False,
               labels=feat_names[np.argsort(pi_mlp.importances_mean)[::-1]], medianprops=dict(color='red'), 
            patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.axvline(0, color="k", ls="--"); plt.grid(alpha=0.3)
plt.subplot(122)
plt.title("Permutation Importance – XGBoost")
plt.boxplot(np.log10(pi_xgb.importances.T[:, np.argsort(pi_xgb.importances_mean)[::-1]]*150), vert=False,
               labels=feat_names[np.argsort(pi_xgb.importances_mean)[::-1]], medianprops=dict(color='red'), 
            patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.axvline(0, color="k", ls="--"); plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
data[var].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()

# %%
data["Lempel-Ziv Complexity"].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()

# %%
data["Shannon Entropy"].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()

# %%
data["Katz Fractal Dim."].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()

# %%
data["Higuchi Fractal Dim."].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()

# %%
data["Permutation Entropy"].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()

# %%
data["Approximate Entropy"].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()
# Out:
# Exception ignored in: <function ResourceTracker.__del__ at 0x72458b369bc0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7c273ac59bc0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x701c0d92dbc0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7dd6dc7cdbc0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x76d521669bc0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7018bb4bdbc0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x7cf9fc219bc0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x766e82c69bc0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 82, in __del__
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 91, in _stop
#   File "/usr/lib/python3.13/multiprocessing/resource_tracker.py", line 116, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
