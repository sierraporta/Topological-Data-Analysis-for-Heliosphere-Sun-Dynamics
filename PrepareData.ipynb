# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(["science","nature"])

# %%
data=pd.read_csv("omni2_daily_rnyYpVi15U.lst.txt",delimiter="\s+",names=["YEAR","DOY","Hour","Scalar B, nT","SW Plasma Temperature, K",
                                                                         "SW Proton Density, N/cm^3","SW Plasma Speed, km/s","Alpha/Prot. ratio",
                                                                         "Flow pressure","Kp index","R (Sunspot No.)","Dst-index, nT","f10.7_index"])
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_60843/790978008.py:1: SyntaxWarning: invalid escape sequence '\s'
#   data=pd.read_csv("omni2_daily_rnyYpVi15U.lst.txt",delimiter="\s+",names=["YEAR","DOY","Hour","Scalar B, nT","SW Plasma Temperature, K",

# %%
data.index=pd.to_datetime(pd.date_range("1964-10-01","2025-05-01"))
data=data.drop(columns=["YEAR","DOY","Hour"])

# %%
data
# Out:
#             Scalar B, nT  SW Plasma Temperature, K  SW Proton Density, N/cm^3  \
# 1964-10-01         999.9                 9999999.0                      999.9
# 1964-10-02         999.9                 9999999.0                      999.9
# 1964-10-03         999.9                 9999999.0                      999.9
# 1964-10-04         999.9                 9999999.0                      999.9
# 1964-10-05         999.9                 9999999.0                      999.9
# ...                  ...                       ...                        ...
# 2025-04-27           8.2                   71876.0                        6.9
# 2025-04-28           6.7                   51345.0                        5.3
# 2025-04-29           7.7                   82562.0                        8.0
# 2025-04-30           7.3                   72454.0                       10.8
# 2025-05-01           9.4                  111312.0                       11.5
#
# ...

# %%
fillna,var=[],[]
for i in data.columns:
    print(i,data[i].max())
    fillna.append(data[i].max())
    var.append(i)
varis=pd.DataFrame({"Var":var,"Fill":fillna})
varis
# Out:
# Scalar B, nT 999.9
# SW Plasma Temperature, K 9999999.0
# SW Proton Density, N/cm^3 999.9
# SW Plasma Speed, km/s 9999.0
# Alpha/Prot. ratio 9.999
# Flow pressure 99.99
# Kp index 83
# R (Sunspot No.) 999
# Dst-index, nT 43
# f10.7_index 999.9
#                          Var         Fill
# 0               Scalar B, nT      999.900
# 1   SW Plasma Temperature, K  9999999.000
# 2  SW Proton Density, N/cm^3      999.900
# 3      SW Plasma Speed, km/s     9999.000
# 4          Alpha/Prot. ratio        9.999
# 5              Flow pressure       99.990
# 6                   Kp index       83.000
# 7            R (Sunspot No.)      999.000
# 8              Dst-index, nT       43.000
# 9                f10.7_index      999.900

# %%
varis=varis[(varis.Var!="Kp index")]
varis=varis[(varis.Var!="Dst-index, nT")]
varis
# Out:
#                          Var         Fill
# 0               Scalar B, nT      999.900
# 1   SW Plasma Temperature, K  9999999.000
# 2  SW Proton Density, N/cm^3      999.900
# 3      SW Plasma Speed, km/s     9999.000
# 4          Alpha/Prot. ratio        9.999
# 5              Flow pressure       99.990
# 7            R (Sunspot No.)      999.000
# 9                f10.7_index      999.900

# %%
for i in varis["Var"]:
    data[data==varis[varis["Var"]==i]["Fill"].max()]=np.nan

# %%
data
# Out:
#             Scalar B, nT  SW Plasma Temperature, K  SW Proton Density, N/cm^3  \
# 1964-10-01           NaN                       NaN                        NaN
# 1964-10-02           NaN                       NaN                        NaN
# 1964-10-03           NaN                       NaN                        NaN
# 1964-10-04           NaN                       NaN                        NaN
# 1964-10-05           NaN                       NaN                        NaN
# ...                  ...                       ...                        ...
# 2025-04-27           8.2                   71876.0                        6.9
# 2025-04-28           6.7                   51345.0                        5.3
# 2025-04-29           7.7                   82562.0                        8.0
# 2025-04-30           7.3                   72454.0                       10.8
# 2025-05-01           9.4                  111312.0                       11.5
#
# ...

# %%
data.isnull().sum()/len(data)*100
# Out:
# Scalar B, nT                 10.968004
# SW Plasma Temperature, K     16.142444
# SW Proton Density, N/cm^3    13.959689
# SW Plasma Speed, km/s        10.909255
# Alpha/Prot. ratio            27.919378
# Flow pressure                14.041034
# Kp index                      0.000000
# R (Sunspot No.)               0.004519
# Dst-index, nT                 0.000000
# f10.7_index                   0.076826
# dtype: float64

# %%
cycles=["20u","20d","21u","21d","22u","22d","23u","23d","24u","24d","25u"]
cuts=["1964-10-01","1968-03-01","1976-03-01","1979-12-11","1986-10-01","1989-11-01","1996-08-01","2001-11-01","2008-12-01","2014-04-01","2019-12-01","2024-10-01"]

# %%
len(cycles), len(cuts)
# Out:
# (11, 12)

# %%
c20up=data[(data.index>=cuts[0])&(data.index<=cuts[1])]
c20down=data[(data.index>=cuts[1])&(data.index<=cuts[2])]

c21up=data[(data.index>=cuts[2])&(data.index<=cuts[3])]
c21down=data[(data.index>=cuts[3])&(data.index<=cuts[4])]

c22up=data[(data.index>=cuts[4])&(data.index<=cuts[5])]
c22down=data[(data.index>=cuts[5])&(data.index<=cuts[6])]

c23up=data[(data.index>=cuts[6])&(data.index<=cuts[7])]
c23down=data[(data.index>=cuts[7])&(data.index<=cuts[8])]

c24up=data[(data.index>=cuts[8])&(data.index<=cuts[9])]
c24down=data[(data.index>=cuts[9])&(data.index<=cuts[10])]

c25up=data[(data.index>=cuts[10])&(data.index<=cuts[11])]

# %%
c25up
# Out:
#             Scalar B, nT  SW Plasma Temperature, K  SW Proton Density, N/cm^3  \
# 2019-12-01           3.9                   43512.0                        9.6
# 2019-12-02           3.0                   20822.0                        9.1
# 2019-12-03           2.2                   15066.0                        9.3
# 2019-12-04           3.1                   21694.0                       15.1
# 2019-12-05           3.0                   26405.0                       11.4
# ...                  ...                       ...                        ...
# 2024-09-27           5.5                   43700.0                        6.6
# 2024-09-28           5.9                   45245.0                        8.4
# 2024-09-29           9.2                  138847.0                       12.1
# 2024-09-30           8.3                  147140.0                        3.6
# 2024-10-01           6.2                   93912.0                        3.4
#
# ...

# %%
alldatas=[c20up,c20down,c21up,c21down,c22up,c22down,c23up,c23down,c24up,c24down,c25up]

# %%
c20up.isnull().sum()/len(c20up)*100
# Out:
# Scalar B, nT                  38.141026
# SW Plasma Temperature, K      35.336538
# SW Proton Density, N/cm^3     35.336538
# SW Plasma Speed, km/s         16.987179
# Alpha/Prot. ratio            100.000000
# Flow pressure                 35.336538
# Kp index                       0.000000
# R (Sunspot No.)                0.000000
# Dst-index, nT                  0.000000
# f10.7_index                    0.240385
# dtype: float64

# %%
c20down.isnull().sum()/len(c20down)*100
# Out:
# Scalar B, nT                  7.800205
# SW Plasma Temperature, K     35.135135
# SW Proton Density, N/cm^3    31.577147
# SW Plasma Speed, km/s        18.611016
# Alpha/Prot. ratio            53.027711
# Flow pressure                31.577147
# Kp index                      0.000000
# R (Sunspot No.)               0.000000
# Dst-index, nT                 0.000000
# f10.7_index                   0.034211
# dtype: float64

# %%
c21up.isnull().sum()/len(c21up)*100
# Out:
# Scalar B, nT                 19.551050
# SW Plasma Temperature, K      5.430847
# SW Proton Density, N/cm^3     5.430847
# SW Plasma Speed, km/s         4.417089
# Alpha/Prot. ratio            33.960898
# Flow pressure                 5.430847
# Kp index                      0.000000
# R (Sunspot No.)               0.000000
# Dst-index, nT                 0.000000
# f10.7_index                   0.000000
# dtype: float64

# %%
c21down.isnull().sum()/len(c21down)*100
# Out:
# Scalar B, nT                 17.571371
# SW Plasma Temperature, K     38.962606
# SW Proton Density, N/cm^3    23.602734
# SW Plasma Speed, km/s        23.602734
# Alpha/Prot. ratio            50.824286
# Flow pressure                23.602734
# Kp index                      0.000000
# R (Sunspot No.)               0.000000
# Dst-index, nT                 0.000000
# f10.7_index                   0.040209
# dtype: float64

# %%
c22up.isnull().sum()/len(c22up)*100
# Out:
# Scalar B, nT                 31.914894
# SW Plasma Temperature, K     32.712766
# SW Proton Density, N/cm^3    32.712766
# SW Plasma Speed, km/s        32.712766
# Alpha/Prot. ratio            35.283688
# Flow pressure                32.712766
# Kp index                      0.000000
# R (Sunspot No.)               0.000000
# Dst-index, nT                 0.000000
# f10.7_index                   0.000000
# dtype: float64

# %%
c22down.isnull().sum()/len(c22down)*100
# Out:
# Scalar B, nT                 24.939173
# SW Plasma Temperature, K     25.871857
# SW Proton Density, N/cm^3    25.871857
# SW Plasma Speed, km/s        25.871857
# Alpha/Prot. ratio            29.643147
# Flow pressure                25.871857
# Kp index                      0.000000
# R (Sunspot No.)               0.000000
# Dst-index, nT                 0.000000
# f10.7_index                   0.040552
# dtype: float64

# %%
c23up.isnull().sum()/len(c23up)*100
# Out:
# Scalar B, nT                 0.052110
# SW Plasma Temperature, K     1.615425
# SW Proton Density, N/cm^3    1.615425
# SW Plasma Speed, km/s        0.052110
# Alpha/Prot. ratio            6.930693
# Flow pressure                1.615425
# Kp index                     0.000000
# R (Sunspot No.)              0.000000
# Dst-index, nT                0.000000
# f10.7_index                  0.000000
# dtype: float64

# %%
c23down.isnull().sum()/len(c23down)*100
# Out:
# Scalar B, nT                 0.000000
# SW Plasma Temperature, K     0.850077
# SW Proton Density, N/cm^3    0.850077
# SW Plasma Speed, km/s        0.077280
# Alpha/Prot. ratio            8.693972
# Flow pressure                0.850077
# Kp index                     0.000000
# R (Sunspot No.)              0.000000
# Dst-index, nT                0.000000
# f10.7_index                  0.231839
# dtype: float64

# %%
c24up.isnull().sum()/len(c24up)*100
# Out:
# Scalar B, nT                 0.000000
# SW Plasma Temperature, K     0.000000
# SW Proton Density, N/cm^3    0.000000
# SW Plasma Speed, km/s        0.000000
# Alpha/Prot. ratio            2.053388
# Flow pressure                0.000000
# Kp index                     0.000000
# R (Sunspot No.)              0.000000
# Dst-index, nT                0.000000
# f10.7_index                  0.154004
# dtype: float64

# %%
c24down.isnull().sum()/len(c24down)*100
# Out:
# Scalar B, nT                 0.000000
# SW Plasma Temperature, K     0.000000
# SW Proton Density, N/cm^3    0.144858
# SW Plasma Speed, km/s        0.000000
# Alpha/Prot. ratio            3.573153
# Flow pressure                0.144858
# Kp index                     0.000000
# R (Sunspot No.)              0.000000
# Dst-index, nT                0.000000
# f10.7_index                  0.048286
# dtype: float64

# %%
c25up.isnull().sum()/len(c25up)*100
# Out:
# Scalar B, nT                 2.263724
# SW Plasma Temperature, K     0.000000
# SW Proton Density, N/cm^3    0.000000
# SW Plasma Speed, km/s        0.000000
# Alpha/Prot. ratio            0.735710
# Flow pressure                1.018676
# Kp index                     0.000000
# R (Sunspot No.)              0.000000
# Dst-index, nT                0.000000
# f10.7_index                  0.056593
# dtype: float64

# %% [markdown]
# ## Inputation process...

# %%
#Regressors:
from sklearn.ensemble import AdaBoostRegressor, BaggingRegressor, ExtraTreesRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import BayesianRidge, GammaRegressor, HuberRegressor, PoissonRegressor, Ridge, TheilSenRegressor, TweedieRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
def inpute(data):
    imp_ET = IterativeImputer(estimator=ExtraTreesRegressor(),verbose=1,add_indicator=False,keep_empty_features=True)
    imp_ET.fit(data)
    df_imp_ET=pd.DataFrame(imp_ET.transform(data),columns=data.columns,index=data.index)
    return df_imp_ET

# %%
c20up
# Out:
#             Scalar B, nT  SW Plasma Temperature, K  SW Proton Density, N/cm^3  \
# 1964-10-01           NaN                       NaN                        NaN
# 1964-10-02           NaN                       NaN                        NaN
# 1964-10-03           NaN                       NaN                        NaN
# 1964-10-04           NaN                       NaN                        NaN
# 1964-10-05           NaN                       NaN                        NaN
# ...                  ...                       ...                        ...
# 1968-02-26           4.6                   42766.0                        6.9
# 1968-02-27           4.6                   65103.0                       17.3
# 1968-02-28          13.7                   79849.0                       22.2
# 1968-02-29           8.2                  131597.0                        4.6
# 1968-03-01           5.9                   68521.0                        2.6
#
# ...

# %%
c20up_inp=inpute(c20up)
c20down_inp=inpute(c20down)
c21up_inp=inpute(c21up)
c21down_inp=inpute(c21down)
c22up_inp=inpute(c22up)
c22down_inp=inpute(c22down)
c23up_inp=inpute(c23up)
c23down_inp=inpute(c23down)
c24up_inp=inpute(c24up)
c24down_inp=inpute(c24down)
c25up_inp=inpute(c25up)
# Out:
# [IterativeImputer] Completing matrix with shape (1248, 10)
# [IterativeImputer] Change: 139861.6260572086, scaled tolerance: 408.382
# [IterativeImputer] Change: 44705.636499999986, scaled tolerance: 408.382
# [IterativeImputer] Change: 25938.805599999992, scaled tolerance: 408.382
# [IterativeImputer] Change: 28740.2001, scaled tolerance: 408.382
# [IterativeImputer] Change: 37485.56980000002, scaled tolerance: 408.382
# [IterativeImputer] Change: 21099.954599999975, scaled tolerance: 408.382
# [IterativeImputer] Change: 19281.572399999972, scaled tolerance: 408.382
# [IterativeImputer] Change: 27173.176099999997, scaled tolerance: 408.382
# [IterativeImputer] Change: 22942.244, scaled tolerance: 408.382
# [IterativeImputer] Change: 20928.9595, scaled tolerance: 408.382
# [IterativeImputer] Completing matrix with shape (1248, 10)
# ...

# %%
c21up
# Out:
#             Scalar B, nT  SW Plasma Temperature, K  SW Proton Density, N/cm^3  \
# 1976-03-01           5.2                  186873.0                        4.1
# 1976-03-02           NaN                  215624.0                        4.0
# 1976-03-03           NaN                  208601.0                        3.0
# 1976-03-04           NaN                       NaN                        NaN
# 1976-03-05           NaN                       NaN                        NaN
# ...                  ...                       ...                        ...
# 1979-12-07           4.8                   30839.0                       10.7
# 1979-12-08           8.7                  124013.0                       14.1
# 1979-12-09           5.5                  110114.0                        3.9
# 1979-12-10           5.3                   78114.0                        5.3
# 1979-12-11           5.4                   59051.0                        5.7
#
# ...

# %%
c21up_inp
# Out:
#             Scalar B, nT  SW Plasma Temperature, K  SW Proton Density, N/cm^3  \
# 1976-03-01         5.200                 186873.00                      4.100
# 1976-03-02         5.785                 215624.00                      4.000
# 1976-03-03         4.911                 208601.00                      3.000
# 1976-03-04         6.258                 116568.13                      7.988
# 1976-03-05         6.410                 120259.60                      7.761
# ...                  ...                       ...                        ...
# 1979-12-07         4.800                  30839.00                     10.700
# 1979-12-08         8.700                 124013.00                     14.100
# 1979-12-09         5.500                 110114.00                      3.900
# 1979-12-10         5.300                  78114.00                      5.300
# 1979-12-11         5.400                  59051.00                      5.700
#
# ...

# %%
alldatas_inp=[c20up_inp,c20down_inp,c21up_inp,c21down_inp,c22up_inp,c22down_inp,c23up_inp,c23down_inp,c24up_inp,c24down_inp,c25up_inp]

# %%
for i in range(len(alldatas)):
    alldatas[i].to_csv("datas/"+cycles[i]+".csv",index=True)
    alldatas_inp[i].to_csv("datas/"+cycles[i]+"_inp.csv",index=True)

# %%
for i,j in zip([c20up,c20down,c21up,c21down,c22up,c22down,c23up,c23down,c24up,c24down,c25up],
               ["c20up","c20down","c21up","c21down","c22up","c22down","c23up","c23down","c24up","c24down","c25up"]):
    print("For cycle {} ({} total data instances)".format(j,len(i)),i.isnull().sum()/len(i)*100)
# Out:
# For cycle c20up (1248 total data instances) Scalar B, nT                  38.141026
# SW Plasma Temperature, K      35.336538
# SW Proton Density, N/cm^3     35.336538
# SW Plasma Speed, km/s         16.987179
# Alpha/Prot. ratio            100.000000
# Flow pressure                 35.336538
# Kp index                       0.000000
# R (Sunspot No.)                0.000000
# Dst-index, nT                  0.000000
# f10.7_index                    0.240385
# dtype: float64
# For cycle c20down (2923 total data instances) Scalar B, nT                  7.800205
# SW Plasma Temperature, K     35.135135
# SW Proton Density, N/cm^3    31.577147
# SW Plasma Speed, km/s        18.611016
# Alpha/Prot. ratio            53.027711
# Flow pressure                31.577147
# Kp index                      0.000000
# R (Sunspot No.)               0.000000
# Dst-index, nT                 0.000000
# f10.7_index                   0.034211
# dtype: float64
# ...

# %%
for i,j in zip([c20up,c20down,c21up,c21down,c22up,c22down,c23up,c23down,c24up,c24down,c25up],
               ["c20up","c20down","c21up","c21down","c22up","c22down","c23up","c23down","c24up","c24down","c25up"]):
    print("For cycle {} ({} total data instances)".format(j,len(i)),i["f10.7_index"].mean())
# Out:
# For cycle c20up (1248 total data instances) 107.99044176706828
# For cycle c20down (2923 total data instances) 116.7753593429158
# For cycle c21up (1381 total data instances) 125.17146994931208
# For cycle c21down (2487 total data instances) 137.70136765888978
# For cycle c22up (1128 total data instances) 137.05744680851063
# For cycle c22down (2466 total data instances) 133.06121703853955
# For cycle c23up (1919 total data instances) 134.91391349661282
# For cycle c23down (2588 total data instances) 107.18113865220762
# For cycle c24up (1948 total data instances) 103.33938303341903
# For cycle c24down (2071 total data instances) 92.58492753623187
# For cycle c25up (1767 total data instances) 121.42083805209514
