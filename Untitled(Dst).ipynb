# %% [markdown]
# # Results.....

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import root_mean_squared_error, r2_score, mean_absolute_percentage_error
import scienceplots
plt.style.use(["science","nature"])
plt.rcParams.update({"font.size": 12,
                    "xtick.labelsize": 12,
                    "ytick.labelsize": 12,
                    "axes.labelsize": 12,
                    'legend.fontsize': 12})
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore")
rs=142
tsize=.35

# %%
var="Dst"
#data = pd.read_csv("datas/dataforR_all.csv",index_col=0)
data = pd.read_csv("datas/dataforDst_all.csv",index_col=0)
#data = pd.read_csv("datas/dataforR_all.csv",index_col=0)
data=data[data.index>="1996-08"] # Only cycl2 24 and 25
data=data.rename(columns={"R (Sunspot)":"R",
                          "f10.7_index":"F10.7",
                          "Dst-index":"Dst",
                          "Scalar B, nT":"B |IMF|",
                          "SW Plasma Temperature, K":"sw Temperature",
                          "SW Proton Density, N/cm^3":"sw Density",
                          "SW Plasma Speed, km/s":"sw Speed",
                          "Alpha/Prot. ratio":"Alpha/Proton ratio"})
print(len(data))
data=data[(data[var]>0)&(data[var]<300)]
print(len(data))
# Out:
# 10289
# 1880

# %%
#from sklearn.preprocessing import StandardScaler, QuantileTransformer
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import mean_squared_error, r2_score
# ─────────────────────────────────────────────
# 1. Pre-procesamiento
# ─────────────────────────────────────────────
#X = data.drop(columns=[var]).values
#y = data[var].values.reshape(-1, 1)

#sc_x, sc_y = StandardScaler(), StandardScaler()
#X_std = sc_x.fit_transform(X).astype(np.float32)
#y_std = sc_y.fit_transform(y).astype(np.float32)
#sc_x, sc_y = QuantileTransformer(random_state=rs), QuantileTransformer(random_state=rs)
#X_std = sc_x.fit_transform(X).astype(np.float32)
#y_std = sc_y.fit_transform(y).astype(np.float32)

#X_tr, X_te, y_tr, y_te = train_test_split(X_std, 
#                                          y_std, 
#                                          test_size=tsize, 
#                                          random_state=rs)

# %%
#pd.DataFrame(y_tr).describe()[0].values

# %%
#pd.DataFrame({"Full original":pd.DataFrame(y).describe()[0].values,
#             "Test scaled":pd.DataFrame(y_te).describe()[0].values,
#             "Train scaled":pd.DataFrame(y_tr).describe()[0].values},
#             index=pd.DataFrame(y_tr).describe().index)

# %%
#plt.figure(figsize=(16,4))
#plt.subplot(131)
#plt.hist(y,bins=50,label="Original"); plt.legend()
#plt.subplot(132)
#plt.hist(y_std,bins=50,label="Transform"); plt.legend()
#plt.subplot(133)
#plt.plot(y_std,label="Time series"); plt.legend()
#plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(16,6))
sns.heatmap(data.corr(), annot=True, cmap="jet")
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['Shannon Entropy', 'Sample Entropy', 'Permutation Entropy',
#        'Spectral Entropy', 'Approximate Entropy', 'Higuchi Fractal Dim.',
#        'Katz Fractal Dim.', 'Petrosian Fractal Dim.', 'Lempel-Ziv Complexity',
#        'Hurst Exponent', 'Dst', 'B |IMF|', 'sw Temperature', 'sw Density',
#        'sw Speed', 'Alpha/Proton ratio'],
#       dtype='object')

# %%
#data=data.drop(columns=['Sample Entropy','Permutation Entropy',"Approximate Entropy","Petrosian Fractal Dim."])

# %%
from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
# ─────────────────────────────────────────────
# 1. Pre-procesamiento
# ─────────────────────────────────────────────
X = data.drop(columns=[var]).values
y = data[var].values.reshape(-1, 1)

#sc_x, sc_y = StandardScaler(), StandardScaler()
#X_std = sc_x.fit_transform(X).astype(np.float32)
#y_std = sc_y.fit_transform(y).astype(np.float32)
sc_x, sc_y = QuantileTransformer(random_state=rs), QuantileTransformer(random_state=rs)
X_std = sc_x.fit_transform(X).astype(np.float32)
y_std = sc_y.fit_transform(y).astype(np.float32)

X_tr, X_te, y_tr, y_te = train_test_split(X_std, 
                                          y_std, 
                                          test_size=tsize, 
                                          random_state=rs)

# %%
pd.DataFrame({"Full original":pd.DataFrame(y).describe()[0].values,
             "Test scaled":pd.DataFrame(y_te).describe()[0].values,
             "Train scaled":pd.DataFrame(y_tr).describe()[0].values},
             index=pd.DataFrame(y_tr).describe().index)
# Out:
#        Full original  Test scaled  Train scaled
# count    1880.000000   658.000000   1222.000000
# mean        5.278191     0.500357      0.481897
# std         4.264505     0.308759      0.302961
# min         1.000000     0.000000      0.000000
# 25%         2.000000     0.230731      0.230731
# 50%         4.000000     0.478478      0.478478
# 75%         7.000000     0.796296      0.738238
# max        43.000000     0.998481      1.000000

# %% [markdown]
# # 1 | Multiple Layer Perceptron - GPU

# %%
# ================================================================
#  MLP con PyTorch + Optuna para búsqueda de hiper-parámetros
#  Dataset: 4 602 × 14   ‒ Target: R
#  CUDA se usa si está disponible (MX250)
#  Requiere: pip install optuna torch torchvision scikit-learn
# ================================================================
import numpy as np, torch, torch.nn as nn, optuna, joblib
from torch.utils.data import TensorDataset, DataLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ─────────────────────────────────────────────
# 2. Definición del modelo
# ─────────────────────────────────────────────
class MLP(nn.Module):
    def __init__(self, in_dim: int,
                 h1: int, h2: int | None, h3: int | None,
                 p_drop: float = 0.2):
        """Hasta 3 capas ocultas; las que tengan None se omiten."""
        super().__init__()
        layers = [nn.Linear(in_dim, h1), nn.ReLU(), nn.Dropout(p_drop)]
        if h2:
            layers += [nn.Linear(h1, h2), nn.ReLU(), nn.Dropout(p_drop)]
            prev = h2
        else:
            prev = h1
        if h3:
            layers += [nn.Linear(prev, h3), nn.ReLU(), nn.Dropout(p_drop)]
            prev = h3
        layers += [nn.Linear(prev, 1)]
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)

# ─────────────────────────────────────────────
# 3. Función de entrenamiento con early-stopping
# ─────────────────────────────────────────────
def train_mlp(params, epochs=500, patience=20):
    model = MLP(
        in_dim=X_tr.shape[1],
        h1=params['h1'],
        h2=params.get('h2'),
        h3=params.get('h3'),
        p_drop=params['dropout']).to(device)

    opt = torch.optim.Adam(
        model.parameters(),
        lr=params['lr'],
        weight_decay=params['weight_decay'])

    batch_size = params['batch']
    ds_train   = TensorDataset(torch.from_numpy(X_tr), torch.from_numpy(y_tr))
    dl_train   = DataLoader(ds_train, batch_size=batch_size, shuffle=True)

    best_val, wait = np.inf, 0
    for _ in range(epochs):
        # ── forward/backward ───────────────────────────────────
        model.train()
        for xb, yb in dl_train:
            xb, yb = xb.to(device), yb.to(device)
            opt.zero_grad()
            loss = nn.functional.mse_loss(model(xb), yb)
            loss.backward()
            opt.step()

        # ── validación rápida ─────────────────────────────────
        model.eval()
        with torch.no_grad():
            preds = model(torch.from_numpy(X_te).to(device)).cpu().numpy()
            val_loss = mean_squared_error(y_te, preds)
        # early stop
        if val_loss < best_val - 1e-4:
            best_val = val_loss
            best_state = model.state_dict()
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    model.load_state_dict(best_state)
    return model, best_val

# ─────────────────────────────────────────────
# 4. Objetivo Optuna
# ─────────────────────────────────────────────
def objective(trial: optuna.Trial) -> float:
    # muestreo de hiper-parámetros
    h1 = trial.suggest_int('h1',       32, 128, step=32)
    h2 = trial.suggest_int('h2',       16, 128, step=16)
    use_h3 = trial.suggest_categorical('use_h3', [False, True])
    h3 = trial.suggest_int('h3', 16, 64, step=16) if use_h3 else None

    params = dict(
        h1       = h1,
        h2       = h2,
        h3       = h3,
        dropout  = trial.suggest_float('dropout', 0.0, 0.4, step=0.1),
        lr       = trial.suggest_float('lr', 1e-4, 5e-3, log=True),
        weight_decay = trial.suggest_float('weight_decay', 1e-5, 1e-2, log=True),
        batch    = trial.suggest_categorical('batch', [64, 128, 256]),
    )

    # entrena y evalúa
    _, val_rmse = train_mlp(params)
    # Optuna minimiza -> devolver RMSE
    return val_rmse

# ─────────────────────────────────────────────
# 5. Ejecución del estudio
# ─────────────────────────────────────────────
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=40, timeout=None, show_progress_bar=True)

print("\n⇢  Mejor RMSE válido  :", study.best_value**0.5)   # pasa de MSE a RMSE
print("⇢  Mejores parámetros :", study.best_params)

joblib.dump(study, "optuna_mlp_study.pkl")

# ─────────────────────────────────────────────
# 6. Entrenamiento final con el mejor conjunto
# ─────────────────────────────────────────────
best_model, _ = train_mlp(study.best_params, epochs=800, patience=30)
# Out:
# [I 2025-07-09 08:28:03,040] A new study created in memory with name: no-name-a53bd6f9-3e9e-4771-a378-1ee9528a0602
# Best trial: 0. Best value: 0.0830676:   2%|▎         | 1/40 [00:03<02:03,  3.17s/it]
# [I 2025-07-09 08:28:06,206] Trial 0 finished with value: 0.08306760340929031 and parameters: {'h1': 64, 'h2': 112, 'use_h3': True, 'h3': 48, 'dropout': 0.30000000000000004, 'lr': 0.0005177063119337391, 'weight_decay': 0.0003882692438928736, 'batch': 64}. Best is trial 0 with value: 0.08306760340929031.
# Best trial: 1. Best value: 0.0829678:   5%|▌         | 2/40 [00:05<01:51,  2.92s/it]
# [I 2025-07-09 08:28:08,958] Trial 1 finished with value: 0.08296780288219452 and parameters: {'h1': 32, 'h2': 64, 'use_h3': False, 'dropout': 0.1, 'lr': 0.00025461103067456913, 'weight_decay': 0.00022734537729411186, 'batch': 64}. Best is trial 1 with value: 0.08296780288219452.
# Best trial: 2. Best value: 0.0803676:   8%|▊         | 3/40 [00:08<01:48,  2.93s/it]
# [I 2025-07-09 08:28:11,887] Trial 2 finished with value: 0.08036758005619049 and parameters: {'h1': 32, 'h2': 128, 'use_h3': False, 'dropout': 0.30000000000000004, 'lr': 0.0019370473493220738, 'weight_decay': 0.00013089485099743127, 'batch': 64}. Best is trial 2 with value: 0.08036758005619049.
# Best trial: 2. Best value: 0.0803676:  10%|█         | 4/40 [00:10<01:28,  2.45s/it]
# [I 2025-07-09 08:28:13,606] Trial 3 finished with value: 0.0823163092136383 and parameters: {'h1': 64, 'h2': 48, 'use_h3': False, 'dropout': 0.2, 'lr': 0.00113199895412195, 'weight_decay': 0.0010577226144335694, 'batch': 64}. Best is trial 2 with value: 0.08036758005619049.
# Best trial: 2. Best value: 0.0803676:  12%|█▎        | 5/40 [00:14<01:41,  2.91s/it]
# [I 2025-07-09 08:28:17,328] Trial 4 finished with value: 0.08571657538414001 and parameters: {'h1': 32, 'h2': 16, 'use_h3': False, 'dropout': 0.2, 'lr': 0.00015609111333280123, 'weight_decay': 1.5524274363362683e-05, 'batch': 256}. Best is trial 2 with value: 0.08036758005619049.
# Best trial: 2. Best value: 0.0803676:  15%|█▌        | 6/40 [00:15<01:16,  2.24s/it]
# [I 2025-07-09 08:28:18,266] Trial 5 finished with value: 0.08278829604387283 and parameters: {'h1': 32, 'h2': 128, 'use_h3': True, 'h3': 32, 'dropout': 0.1, 'lr': 0.002712331077627429, 'weight_decay': 1.4607692309207332e-05, 'batch': 128}. Best is trial 2 with value: 0.08036758005619049.
# Best trial: 2. Best value: 0.0803676:  18%|█▊        | 7/40 [00:18<01:27,  2.64s/it]
# [I 2025-07-09 08:28:21,734] Trial 6 finished with value: 0.08416268229484558 and parameters: {'h1': 128, 'h2': 48, 'use_h3': True, 'h3': 48, 'dropout': 0.30000000000000004, 'lr': 0.00010472331406329816, 'weight_decay': 0.00041357358244830376, 'batch': 64}. Best is trial 2 with value: 0.08036758005619049.
# Best trial: 2. Best value: 0.0803676:  20%|██        | 8/40 [00:20<01:12,  2.26s/it]
# [I 2025-07-09 08:28:23,178] Trial 7 finished with value: 0.08250252157449722 and parameters: {'h1': 64, 'h2': 16, 'use_h3': False, 'dropout': 0.30000000000000004, 'lr': 0.00107164322032795, 'weight_decay': 0.0001679826973530531, 'batch': 128}. Best is trial 2 with value: 0.08036758005619049.
# Best trial: 8. Best value: 0.0788433:  22%|██▎       | 9/40 [00:23<01:17,  2.49s/it]
# [I 2025-07-09 08:28:26,166] Trial 8 finished with value: 0.07884325087070465 and parameters: {'h1': 128, 'h2': 32, 'use_h3': True, 'h3': 16, 'dropout': 0.1, 'lr': 0.0010279769085305332, 'weight_decay': 1.85173783041326e-05, 'batch': 64}. Best is trial 8 with value: 0.07884325087070465.
# Best trial: 8. Best value: 0.0788433:  25%|██▌       | 10/40 [00:24<01:01,  2.05s/it]
# [I 2025-07-09 08:28:27,223] Trial 9 finished with value: 0.08480090647935867 and parameters: {'h1': 96, 'h2': 64, 'use_h3': False, 'dropout': 0.4, 'lr': 0.0002872042811743652, 'weight_decay': 1.0112648461159407e-05, 'batch': 128}. Best is trial 8 with value: 0.07884325087070465.
# Best trial: 8. Best value: 0.0788433:  28%|██▊       | 11/40 [00:24<00:47,  1.64s/it]
# [I 2025-07-09 08:28:27,946] Trial 10 finished with value: 0.08415845036506653 and parameters: {'h1': 128, 'h2': 32, 'use_h3': True, 'h3': 16, 'dropout': 0.0, 'lr': 0.004472069872071681, 'weight_decay': 0.006442940213360363, 'batch': 256}. Best is trial 8 with value: 0.07884325087070465.
# Best trial: 8. Best value: 0.0788433:  30%|███       | 12/40 [00:26<00:46,  1.67s/it]
# [I 2025-07-09 08:28:29,698] Trial 11 finished with value: 0.0795259177684784 and parameters: {'h1': 96, 'h2': 96, 'use_h3': True, 'h3': 16, 'dropout': 0.0, 'lr': 0.001978151764889378, 'weight_decay': 5.5801810874233925e-05, 'batch': 64}. Best is trial 8 with value: 0.07884325087070465.
# Best trial: 8. Best value: 0.0788433:  32%|███▎      | 13/40 [00:28<00:47,  1.75s/it]
# [I 2025-07-09 08:28:31,625] Trial 12 finished with value: 0.08136988431215286 and parameters: {'h1': 96, 'h2': 96, 'use_h3': True, 'h3': 16, 'dropout': 0.0, 'lr': 0.0007016415171878492, 'weight_decay': 5.437247925922988e-05, 'batch': 64}. Best is trial 8 with value: 0.07884325087070465.
# Best trial: 8. Best value: 0.0788433:  35%|███▌      | 14/40 [00:30<00:47,  1.82s/it]
# [I 2025-07-09 08:28:33,614] Trial 13 finished with value: 0.07946424931287766 and parameters: {'h1': 128, 'h2': 96, 'use_h3': True, 'h3': 16, 'dropout': 0.1, 'lr': 0.001819824970463233, 'weight_decay': 4.7071151047178634e-05, 'batch': 64}. Best is trial 8 with value: 0.07884325087070465.
# Best trial: 8. Best value: 0.0788433:  38%|███▊      | 15/40 [00:32<00:42,  1.72s/it]
# [I 2025-07-09 08:28:35,080] Trial 14 finished with value: 0.08129345625638962 and parameters: {'h1': 128, 'h2': 80, 'use_h3': True, 'h3': 32, 'dropout': 0.1, 'lr': 0.0012084182175210857, 'weight_decay': 5.300410242845112e-05, 'batch': 256}. Best is trial 8 with value: 0.07884325087070465.
# Best trial: 8. Best value: 0.0788433:  40%|████      | 16/40 [00:34<00:43,  1.82s/it]
# [I 2025-07-09 08:28:37,131] Trial 15 finished with value: 0.08038146048784256 and parameters: {'h1': 128, 'h2': 80, 'use_h3': True, 'h3': 64, 'dropout': 0.1, 'lr': 0.00462306601252489, 'weight_decay': 3.043706276458761e-05, 'batch': 64}. Best is trial 8 with value: 0.07884325087070465.
# Best trial: 8. Best value: 0.0788433:  42%|████▎     | 17/40 [00:37<00:51,  2.24s/it]
# [I 2025-07-09 08:28:40,348] Trial 16 finished with value: 0.0814034715294838 and parameters: {'h1': 96, 'h2': 96, 'use_h3': True, 'h3': 16, 'dropout': 0.2, 'lr': 0.00046651013718001404, 'weight_decay': 2.8492849652312287e-05, 'batch': 64}. Best is trial 8 with value: 0.07884325087070465.
# Best trial: 17. Best value: 0.0774794:  45%|████▌     | 18/40 [00:42<01:05,  2.98s/it]
# [I 2025-07-09 08:28:45,046] Trial 17 finished with value: 0.07747944444417953 and parameters: {'h1': 128, 'h2': 48, 'use_h3': True, 'h3': 32, 'dropout': 0.1, 'lr': 0.002575331927234403, 'weight_decay': 9.53786585569253e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  48%|████▊     | 19/40 [00:43<00:51,  2.45s/it]
# [I 2025-07-09 08:28:46,255] Trial 18 finished with value: 0.08039002865552902 and parameters: {'h1': 128, 'h2': 32, 'use_h3': True, 'h3': 32, 'dropout': 0.0, 'lr': 0.002883829429866033, 'weight_decay': 0.00010866490416512866, 'batch': 128}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  50%|█████     | 20/40 [00:44<00:44,  2.24s/it]
# [I 2025-07-09 08:28:48,004] Trial 19 finished with value: 0.08293361961841583 and parameters: {'h1': 96, 'h2': 48, 'use_h3': True, 'h3': 32, 'dropout': 0.1, 'lr': 0.0007894265834391133, 'weight_decay': 0.0010660672127467752, 'batch': 256}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  52%|█████▎    | 21/40 [00:46<00:40,  2.13s/it]
# [I 2025-07-09 08:28:49,886] Trial 20 finished with value: 0.08492717891931534 and parameters: {'h1': 128, 'h2': 32, 'use_h3': True, 'h3': 48, 'dropout': 0.2, 'lr': 0.0028361994693153624, 'weight_decay': 0.006273247118112287, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  55%|█████▌    | 22/40 [00:49<00:41,  2.29s/it]
# [I 2025-07-09 08:28:52,542] Trial 21 finished with value: 0.07933445274829865 and parameters: {'h1': 128, 'h2': 64, 'use_h3': True, 'h3': 16, 'dropout': 0.1, 'lr': 0.001529732498171172, 'weight_decay': 2.877116965863339e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  57%|█████▊    | 23/40 [00:52<00:42,  2.53s/it]
# [I 2025-07-09 08:28:55,623] Trial 22 finished with value: 0.08055431395769119 and parameters: {'h1': 128, 'h2': 64, 'use_h3': True, 'h3': 16, 'dropout': 0.1, 'lr': 0.0015700482082855831, 'weight_decay': 2.3862760577514333e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  60%|██████    | 24/40 [00:56<00:45,  2.83s/it]
# [I 2025-07-09 08:28:59,160] Trial 23 finished with value: 0.08038997650146484 and parameters: {'h1': 96, 'h2': 48, 'use_h3': True, 'h3': 32, 'dropout': 0.2, 'lr': 0.0008321941602316715, 'weight_decay': 7.906913779366389e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  62%|██████▎   | 25/40 [00:58<00:39,  2.66s/it]
# [I 2025-07-09 08:29:01,439] Trial 24 finished with value: 0.08141002804040909 and parameters: {'h1': 128, 'h2': 32, 'use_h3': True, 'h3': 16, 'dropout': 0.0, 'lr': 0.0014190931206583095, 'weight_decay': 2.4252569234470464e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  65%|██████▌   | 26/40 [01:00<00:34,  2.46s/it]
# [I 2025-07-09 08:29:03,417] Trial 25 finished with value: 0.08114377409219742 and parameters: {'h1': 128, 'h2': 16, 'use_h3': True, 'h3': 32, 'dropout': 0.1, 'lr': 0.0031321984396792306, 'weight_decay': 1.343569270998943e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  68%|██████▊   | 27/40 [01:04<00:38,  2.95s/it]
# [I 2025-07-09 08:29:07,528] Trial 26 finished with value: 0.07996099442243576 and parameters: {'h1': 96, 'h2': 64, 'use_h3': True, 'h3': 64, 'dropout': 0.2, 'lr': 0.0004937960804952348, 'weight_decay': 8.311778071167408e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  70%|███████   | 28/40 [01:06<00:31,  2.59s/it]
# [I 2025-07-09 08:29:09,267] Trial 27 finished with value: 0.08235078305006027 and parameters: {'h1': 128, 'h2': 48, 'use_h3': True, 'h3': 16, 'dropout': 0.1, 'lr': 0.0020376476948461867, 'weight_decay': 0.0007541182984184335, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  72%|███████▎  | 29/40 [01:06<00:22,  2.03s/it]
# [I 2025-07-09 08:29:10,001] Trial 28 finished with value: 0.08332526683807373 and parameters: {'h1': 96, 'h2': 80, 'use_h3': True, 'h3': 32, 'dropout': 0.0, 'lr': 0.0036677154009614877, 'weight_decay': 0.0030779807700794548, 'batch': 256}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  75%|███████▌  | 30/40 [01:08<00:19,  1.95s/it]
# [I 2025-07-09 08:29:11,772] Trial 29 finished with value: 0.08621983975172043 and parameters: {'h1': 64, 'h2': 32, 'use_h3': True, 'h3': 16, 'dropout': 0.4, 'lr': 0.0009583860521562998, 'weight_decay': 0.00023192217811477935, 'batch': 128}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  78%|███████▊  | 31/40 [01:13<00:24,  2.74s/it]
# [I 2025-07-09 08:29:16,348] Trial 30 finished with value: 0.08113616704940796 and parameters: {'h1': 128, 'h2': 48, 'use_h3': True, 'h3': 48, 'dropout': 0.2, 'lr': 0.0003651431404932585, 'weight_decay': 0.0003651969989960144, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  80%|████████  | 32/40 [01:16<00:23,  2.92s/it]
# [I 2025-07-09 08:29:19,682] Trial 31 finished with value: 0.08031705021858215 and parameters: {'h1': 128, 'h2': 112, 'use_h3': True, 'h3': 16, 'dropout': 0.1, 'lr': 0.0016175231485553146, 'weight_decay': 3.891122352564419e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  82%|████████▎ | 33/40 [01:19<00:20,  2.90s/it]
# [I 2025-07-09 08:29:22,524] Trial 32 finished with value: 0.08137937635183334 and parameters: {'h1': 128, 'h2': 64, 'use_h3': True, 'h3': 16, 'dropout': 0.1, 'lr': 0.0006296670682502019, 'weight_decay': 4.272220355803648e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  85%|████████▌ | 34/40 [01:22<00:17,  2.96s/it]
# [I 2025-07-09 08:29:25,647] Trial 33 finished with value: 0.07983953505754471 and parameters: {'h1': 128, 'h2': 80, 'use_h3': True, 'h3': 16, 'dropout': 0.1, 'lr': 0.002205781444624405, 'weight_decay': 2.0285326101805193e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  88%|████████▊ | 35/40 [01:25<00:14,  2.82s/it]
# [I 2025-07-09 08:29:28,140] Trial 34 finished with value: 0.07942166179418564 and parameters: {'h1': 128, 'h2': 96, 'use_h3': False, 'dropout': 0.1, 'lr': 0.0013304448486930935, 'weight_decay': 9.516084641274831e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  90%|█████████ | 36/40 [01:27<00:10,  2.65s/it]
# [I 2025-07-09 08:29:30,389] Trial 35 finished with value: 0.08066089451313019 and parameters: {'h1': 128, 'h2': 112, 'use_h3': False, 'dropout': 0.2, 'lr': 0.0013360630589756071, 'weight_decay': 8.871337461411913e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  92%|█████████▎| 37/40 [01:28<00:06,  2.32s/it]
# [I 2025-07-09 08:29:31,925] Trial 36 finished with value: 0.08000227063894272 and parameters: {'h1': 96, 'h2': 64, 'use_h3': False, 'dropout': 0.0, 'lr': 0.002403260029424081, 'weight_decay': 0.00015290790954800045, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  95%|█████████▌| 38/40 [01:31<00:04,  2.40s/it]
# [I 2025-07-09 08:29:34,511] Trial 37 finished with value: 0.08072807639837265 and parameters: {'h1': 128, 'h2': 128, 'use_h3': False, 'dropout': 0.1, 'lr': 0.0009482716642073146, 'weight_decay': 0.0002566970283278645, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794:  98%|█████████▊| 39/40 [01:32<00:02,  2.10s/it]
# [I 2025-07-09 08:29:35,913] Trial 38 finished with value: 0.08389662206172943 and parameters: {'h1': 32, 'h2': 48, 'use_h3': False, 'dropout': 0.2, 'lr': 0.0005988040254374665, 'weight_decay': 1.0345039712615092e-05, 'batch': 64}. Best is trial 17 with value: 0.07747944444417953.
# Best trial: 17. Best value: 0.0774794: 100%|██████████| 40/40 [01:34<00:00,  2.36s/it]
# [I 2025-07-09 08:29:37,559] Trial 39 finished with value: 0.0806691125035286 and parameters: {'h1': 128, 'h2': 16, 'use_h3': False, 'dropout': 0.1, 'lr': 0.001244738966078539, 'weight_decay': 1.7661958524142476e-05, 'batch': 128}. Best is trial 17 with value: 0.07747944444417953.
#
# ⇢  Mejor RMSE válido  : 0.27835129682503645
# ⇢  Mejores parámetros : {'h1': 128, 'h2': 48, 'use_h3': True, 'h3': 32, 'dropout': 0.1, 'lr': 0.002575331927234403, 'weight_decay': 9.53786585569253e-05, 'batch': 64}

# %%
# ── Métricas finales en escala original ──────
with torch.no_grad():
    best_model.eval()
    preds_te_std = best_model(torch.from_numpy(X_te).to(device)).cpu().numpy()
    preds_tr_std = best_model(torch.from_numpy(X_tr).to(device)).cpu().numpy()

y_te_inv  = sc_y.inverse_transform(y_te)
y_tr_inv  = sc_y.inverse_transform(y_tr)
preds_te  = sc_y.inverse_transform(preds_te_std)
preds_tr  = sc_y.inverse_transform(preds_tr_std)

print("R² test :", r2_score(y_te_inv, preds_te))
print("RMSE test:", mean_squared_error(y_te_inv, preds_te, squared=False))
print("R² train:", r2_score(y_tr_inv, preds_tr))
print("RMSE train:", mean_squared_error(y_tr_inv, preds_tr, squared=False))
# Out:
# R² test : -0.006368756294250488
# RMSE test: 4.2952704
# R² train: 0.16962051391601562
# RMSE train: 3.8733847

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Predictions")
plt.scatter(y_tr_inv,preds_tr,label="Train")
plt.scatter(y_te_inv,preds_te,label="Test")
plt.legend()
plt.subplot(122)
plt.title("Resisuals")
plt.scatter(y_tr_inv,preds_tr-y_tr_inv,label="Train")
plt.scatter(y_te_inv,preds_te-y_te_inv,label="Test")
plt.legend()
plt.show()

# %% [markdown]
# # 3 | XGBoost GPU

# %%
import xgboost as xgb
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
import optuna, numpy as np

dtrain, dtest = xgb.DMatrix(X_tr, label=y_tr), xgb.DMatrix(X_te, label=y_te)

# ── ¿XGBoost tiene GPU? ───────────────────────────────
def xgb_gpu_available() -> bool:
    try:
        # Desde XGB 2.0 existe esto:
        return xgb.core._has_cuda_support()
    except AttributeError:
        # Fallback: intenta una llamada dummy
        try:
            xgb.train({'tree_method':'gpu_hist'}, dtrain, num_boost_round=1, verbose_eval=False)
            return True
        except xgb.core.XGBoostError:
            return False

USE_GPU = xgb_gpu_available()
print("XGBoost GPU disponible?:", USE_GPU)

tree_method = 'gpu_hist' if USE_GPU else 'hist'

# ── Optuna objective ──────────────────────────────────

def objective(trial):
    param = {
        "objective": "reg:squarederror",
        "tree_method": tree_method,          # 'gpu_hist' o 'hist'
        "learning_rate": trial.suggest_float("eta", 0.02, 0.15, log=True),
        "max_depth": trial.suggest_int("max_depth", 1, 4),
        "subsample": trial.suggest_float("subsample", 0.5, 0.9),
        "colsample_bytree": trial.suggest_float("colsample", 0.4, 0.9),
        "lambda": trial.suggest_float("lambda", 1.0, 10.0, log=True),
        "alpha": trial.suggest_float("alpha", 0.0, 1.0),
        "min_child_weight": trial.suggest_float("min_child_weight", 5, 10, log=True),
    }
    n_rounds = trial.suggest_int("n_rounds", 500, 3000, step=500)

    booster = xgb.train(
        param,
        dtrain,
        num_boost_round=n_rounds,
        evals=[(dtest, "val")],
        verbose_eval=False,
        early_stopping_rounds=50,
    )
    preds = booster.predict(dtest)
    return mean_squared_error(y_te, preds)          # Optuna minimiza

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50, show_progress_bar=True, timeout=None)

best_params = study.best_params | {
    "objective": "reg:squarederror",
    "tree_method": tree_method
}
best_rounds = best_params.pop("n_rounds")
booster = xgb.train(best_params, dtrain,
                    num_boost_round=best_rounds,
                    evals=[(dtest, "val")],
                    early_stopping_rounds=50,
                    verbose_eval=False)
# Out:
# [I 2025-07-09 08:29:41,082] A new study created in memory with name: no-name-53410e44-47d7-4514-b45b-a8f8838b561b
# XGBoost GPU disponible?: False
# Best trial: 0. Best value: 0.0820729:   4%|▍         | 2/50 [00:00<00:03, 13.03it/s]
# [I 2025-07-09 08:29:41,157] Trial 0 finished with value: 0.08207286149263382 and parameters: {'eta': 0.054083768560878744, 'max_depth': 3, 'subsample': 0.6141746650024067, 'colsample': 0.5487145585208234, 'lambda': 1.2190878648895709, 'alpha': 0.4139849265001022, 'min_child_weight': 6.170095045501911, 'n_rounds': 1500}. Best is trial 0 with value: 0.08207286149263382.
# [I 2025-07-09 08:29:41,234] Trial 1 finished with value: 0.0834536924958229 and parameters: {'eta': 0.039242348139314535, 'max_depth': 1, 'subsample': 0.6351562995736298, 'colsample': 0.8896228739060255, 'lambda': 1.3140845469354165, 'alpha': 0.5018026902652414, 'min_child_weight': 5.54032007202866, 'n_rounds': 1500}. Best is trial 0 with value: 0.08207286149263382.
# Best trial: 2. Best value: 0.0817012:   4%|▍         | 2/50 [00:00<00:03, 13.03it/s]
# [I 2025-07-09 08:29:41,329] Trial 2 finished with value: 0.08170117437839508 and parameters: {'eta': 0.05701537838861166, 'max_depth': 4, 'subsample': 0.7890457681266532, 'colsample': 0.4814319194170218, 'lambda': 6.039057163420824, 'alpha': 0.44479508321758443, 'min_child_weight': 5.87013598110485, 'n_rounds': 1000}. Best is trial 2 with value: 0.08170117437839508.
# Best trial: 2. Best value: 0.0817012:   8%|▊         | 4/50 [00:00<00:03, 11.96it/s]
# [I 2025-07-09 08:29:41,411] Trial 3 finished with value: 0.08351310342550278 and parameters: {'eta': 0.0754306253277348, 'max_depth': 1, 'subsample': 0.8371332050824207, 'colsample': 0.6879949313508623, 'lambda': 9.087922507410303, 'alpha': 0.7850979044224832, 'min_child_weight': 8.278719200177942, 'n_rounds': 3000}. Best is trial 2 with value: 0.08170117437839508.
# [I 2025-07-09 08:29:41,486] Trial 4 finished with value: 0.08248545229434967 and parameters: {'eta': 0.06833066192297264, 'max_depth': 2, 'subsample': 0.680386383051616, 'colsample': 0.6087298003958057, 'lambda': 5.08365149825681, 'alpha': 0.8920558734155744, 'min_child_weight': 7.30038647600391, 'n_rounds': 2000}. Best is trial 2 with value: 0.08170117437839508.
# Best trial: 2. Best value: 0.0817012:  10%|█         | 5/50 [00:00<00:03, 11.96it/s]
# [I 2025-07-09 08:29:41,611] Trial 5 finished with value: 0.08360863476991653 and parameters: {'eta': 0.02352906845493577, 'max_depth': 1, 'subsample': 0.595505997206848, 'colsample': 0.4348632975702544, 'lambda': 1.8302438618518737, 'alpha': 0.8874857259394746, 'min_child_weight': 7.076839219278148, 'n_rounds': 3000}. Best is trial 2 with value: 0.08170117437839508.
# Best trial: 7. Best value: 0.0810973:  16%|█▌        | 8/50 [00:00<00:03, 12.24it/s]
# [I 2025-07-09 08:29:41,672] Trial 6 finished with value: 0.08298429846763611 and parameters: {'eta': 0.12701084906555613, 'max_depth': 2, 'subsample': 0.8110961873646196, 'colsample': 0.6144692404462568, 'lambda': 4.065801368737857, 'alpha': 0.19988759372290854, 'min_child_weight': 7.122300123776574, 'n_rounds': 2000}. Best is trial 2 with value: 0.08170117437839508.
# [I 2025-07-09 08:29:41,745] Trial 7 finished with value: 0.08109733462333679 and parameters: {'eta': 0.05964308675377713, 'max_depth': 2, 'subsample': 0.590717324713277, 'colsample': 0.54834712464839, 'lambda': 2.1798690802360707, 'alpha': 0.11725034421306069, 'min_child_weight': 9.871541217119251, 'n_rounds': 2000}. Best is trial 7 with value: 0.08109733462333679.
# Best trial: 7. Best value: 0.0810973:  16%|█▌        | 8/50 [00:00<00:03, 12.24it/s]
# [I 2025-07-09 08:29:41,833] Trial 8 finished with value: 0.08325956016778946 and parameters: {'eta': 0.1094848446441303, 'max_depth': 4, 'subsample': 0.5711709644844314, 'colsample': 0.567405534617839, 'lambda': 5.693846918230118, 'alpha': 0.869514675632772, 'min_child_weight': 8.009053663206217, 'n_rounds': 1000}. Best is trial 7 with value: 0.08109733462333679.
# Best trial: 7. Best value: 0.0810973:  20%|██        | 10/50 [00:00<00:03, 11.42it/s]
# [I 2025-07-09 08:29:41,941] Trial 9 finished with value: 0.08189550042152405 and parameters: {'eta': 0.026910947695655246, 'max_depth': 3, 'subsample': 0.8967378418231436, 'colsample': 0.6375669118876556, 'lambda': 6.753161449820815, 'alpha': 0.10632579712415002, 'min_child_weight': 6.47584992142308, 'n_rounds': 500}. Best is trial 7 with value: 0.08109733462333679.
# Best trial: 10. Best value: 0.0809901:  20%|██        | 10/50 [00:01<00:03, 11.42it/s]
# [I 2025-07-09 08:29:42,109] Trial 10 finished with value: 0.08099006116390228 and parameters: {'eta': 0.03721493237419895, 'max_depth': 2, 'subsample': 0.5135582128473839, 'colsample': 0.7553933294783235, 'lambda': 2.5550842008262675, 'alpha': 0.05634320853019608, 'min_child_weight': 9.956267196196254, 'n_rounds': 2500}. Best is trial 10 with value: 0.08099006116390228.
# Best trial: 10. Best value: 0.0809901:  24%|██▍       | 12/50 [00:01<00:03,  9.76it/s]
# [I 2025-07-09 08:29:42,205] Trial 11 finished with value: 0.08241589367389679 and parameters: {'eta': 0.037510842043554884, 'max_depth': 2, 'subsample': 0.5051133282796084, 'colsample': 0.7387548828762567, 'lambda': 2.5555043856292943, 'alpha': 0.01708830319453534, 'min_child_weight': 9.802922115110492, 'n_rounds': 2500}. Best is trial 10 with value: 0.08099006116390228.
# Best trial: 10. Best value: 0.0809901:  24%|██▍       | 12/50 [00:01<00:03,  9.76it/s]
# [I 2025-07-09 08:29:42,348] Trial 12 finished with value: 0.08173497766256332 and parameters: {'eta': 0.03722793475551656, 'max_depth': 2, 'subsample': 0.5036995257722502, 'colsample': 0.7844479818726121, 'lambda': 2.65536362964276, 'alpha': 0.2557350460539036, 'min_child_weight': 9.774581952308424, 'n_rounds': 2500}. Best is trial 10 with value: 0.08099006116390228.
# Best trial: 10. Best value: 0.0809901:  30%|███       | 15/50 [00:01<00:03,  9.48it/s]
# [I 2025-07-09 08:29:42,430] Trial 13 finished with value: 0.08305278420448303 and parameters: {'eta': 0.08415626790059992, 'max_depth': 3, 'subsample': 0.5488124052871787, 'colsample': 0.8160861511542348, 'lambda': 1.8892625762931343, 'alpha': 0.0120580086573941, 'min_child_weight': 8.79553744860594, 'n_rounds': 2500}. Best is trial 10 with value: 0.08099006116390228.
# [I 2025-07-09 08:29:42,534] Trial 14 finished with value: 0.08235051482915878 and parameters: {'eta': 0.04744904579015673, 'max_depth': 2, 'subsample': 0.7151832895286061, 'colsample': 0.7090306210245925, 'lambda': 3.6935276578690948, 'alpha': 0.2862638222520923, 'min_child_weight': 8.983735939516029, 'n_rounds': 2000}. Best is trial 10 with value: 0.08099006116390228.
# Best trial: 10. Best value: 0.0809901:  32%|███▏      | 16/50 [00:01<00:04,  8.31it/s]
# [I 2025-07-09 08:29:42,709] Trial 15 finished with value: 0.0814891904592514 and parameters: {'eta': 0.027005042977614975, 'max_depth': 3, 'subsample': 0.6744301945008838, 'colsample': 0.5196614425330346, 'lambda': 1.744357872231098, 'alpha': 0.7025160774712704, 'min_child_weight': 5.1516158690798886, 'n_rounds': 2500}. Best is trial 10 with value: 0.08099006116390228.
# [I 2025-07-09 08:29:42,805] Trial 16 finished with value: 0.08281079679727554 and parameters: {'eta': 0.09536214833628157, 'max_depth': 1, 'subsample': 0.5334571858551129, 'colsample': 0.41646225440447077, 'lambda': 2.821048617493985, 'alpha': 0.1491791351506732, 'min_child_weight': 9.976465112996495, 'n_rounds': 3000}. Best is trial 10 with value: 0.08099006116390228.
# Best trial: 18. Best value: 0.0804058:  38%|███▊      | 19/50 [00:01<00:03,  8.25it/s]
# [I 2025-07-09 08:29:42,965] Trial 17 finished with value: 0.08181998878717422 and parameters: {'eta': 0.03218505584901254, 'max_depth': 2, 'subsample': 0.7466184694751998, 'colsample': 0.8784522533255983, 'lambda': 1.005632160069702, 'alpha': 0.5766034512881897, 'min_child_weight': 9.030030265540706, 'n_rounds': 1500}. Best is trial 10 with value: 0.08099006116390228.
# [I 2025-07-09 08:29:43,079] Trial 18 finished with value: 0.08040577918291092 and parameters: {'eta': 0.04775931442909682, 'max_depth': 3, 'subsample': 0.6449496902164544, 'colsample': 0.7807409276083619, 'lambda': 3.5187521019368067, 'alpha': 0.32674745842749914, 'min_child_weight': 7.8557719237321635, 'n_rounds': 2000}. Best is trial 18 with value: 0.08040577918291092.
# Best trial: 18. Best value: 0.0804058:  42%|████▏     | 21/50 [00:02<00:04,  6.58it/s]
# [I 2025-07-09 08:29:43,284] Trial 19 finished with value: 0.08066032826900482 and parameters: {'eta': 0.020222554636566106, 'max_depth': 4, 'subsample': 0.6446917894970953, 'colsample': 0.7949255840119487, 'lambda': 3.7591680854268152, 'alpha': 0.3221788867202516, 'min_child_weight': 7.8795909369814465, 'n_rounds': 2500}. Best is trial 18 with value: 0.08040577918291092.
# [I 2025-07-09 08:29:43,470] Trial 20 finished with value: 0.08095933496952057 and parameters: {'eta': 0.02202358409612137, 'max_depth': 4, 'subsample': 0.6445639380088412, 'colsample': 0.8306348319054583, 'lambda': 3.91257699165711, 'alpha': 0.3189674319076832, 'min_child_weight': 7.633399953415296, 'n_rounds': 1000}. Best is trial 18 with value: 0.08040577918291092.
# Best trial: 18. Best value: 0.0804058:  44%|████▍     | 22/50 [00:02<00:04,  6.05it/s]
# [I 2025-07-09 08:29:43,672] Trial 21 finished with value: 0.08094587922096252 and parameters: {'eta': 0.021081774306860455, 'max_depth': 4, 'subsample': 0.6364971751060375, 'colsample': 0.807480836724745, 'lambda': 3.691161071398273, 'alpha': 0.3389801603081434, 'min_child_weight': 7.72664494862636, 'n_rounds': 500}. Best is trial 18 with value: 0.08040577918291092.
# Best trial: 22. Best value: 0.0796829:  48%|████▊     | 24/50 [00:03<00:04,  5.25it/s]
# [I 2025-07-09 08:29:43,936] Trial 22 finished with value: 0.07968291640281677 and parameters: {'eta': 0.021330719545557066, 'max_depth': 4, 'subsample': 0.7191157141657405, 'colsample': 0.8210509255170281, 'lambda': 3.392363643307121, 'alpha': 0.3561545613214238, 'min_child_weight': 6.6813744090769385, 'n_rounds': 500}. Best is trial 22 with value: 0.07968291640281677.
# [I 2025-07-09 08:29:44,122] Trial 23 finished with value: 0.07998784631490707 and parameters: {'eta': 0.028205041602363257, 'max_depth': 4, 'subsample': 0.7121147549569674, 'colsample': 0.85333885390171, 'lambda': 4.852232654029401, 'alpha': 0.5778466426823033, 'min_child_weight': 6.64882317856316, 'n_rounds': 1500}. Best is trial 22 with value: 0.07968291640281677.
# Best trial: 25. Best value: 0.0792519:  52%|█████▏    | 26/50 [00:03<00:04,  5.32it/s]
# [I 2025-07-09 08:29:44,309] Trial 24 finished with value: 0.07945002615451813 and parameters: {'eta': 0.02587851634950938, 'max_depth': 4, 'subsample': 0.7256482720134693, 'colsample': 0.8525194032709407, 'lambda': 4.6610106112010765, 'alpha': 0.6154164339883226, 'min_child_weight': 6.6837303785319016, 'n_rounds': 500}. Best is trial 24 with value: 0.07945002615451813.
# [I 2025-07-09 08:29:44,494] Trial 25 finished with value: 0.07925194501876831 and parameters: {'eta': 0.027579031105271563, 'max_depth': 4, 'subsample': 0.7427875023223602, 'colsample': 0.8554197667153685, 'lambda': 4.7996731250935145, 'alpha': 0.6262737986342519, 'min_child_weight': 6.574098444581947, 'n_rounds': 500}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  56%|█████▌    | 28/50 [00:03<00:04,  5.36it/s]
# [I 2025-07-09 08:29:44,684] Trial 26 finished with value: 0.07982052117586136 and parameters: {'eta': 0.03078962519347469, 'max_depth': 4, 'subsample': 0.7467982830278977, 'colsample': 0.8990598824540559, 'lambda': 7.898262283818814, 'alpha': 0.6751136784929637, 'min_child_weight': 6.635756099894025, 'n_rounds': 500}. Best is trial 25 with value: 0.07925194501876831.
# [I 2025-07-09 08:29:44,866] Trial 27 finished with value: 0.08012069761753082 and parameters: {'eta': 0.025409637640026204, 'max_depth': 4, 'subsample': 0.7545231983636654, 'colsample': 0.8452403872732107, 'lambda': 4.356808788064469, 'alpha': 0.6156867827086369, 'min_child_weight': 6.106763570165961, 'n_rounds': 500}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  60%|██████    | 30/50 [00:04<00:03,  6.15it/s]
# [I 2025-07-09 08:29:45,004] Trial 28 finished with value: 0.08161241561174393 and parameters: {'eta': 0.03187930003765756, 'max_depth': 3, 'subsample': 0.7731267382490744, 'colsample': 0.683303831378175, 'lambda': 7.022507030322837, 'alpha': 0.9945890251975646, 'min_child_weight': 6.748879547395375, 'n_rounds': 1000}. Best is trial 25 with value: 0.07925194501876831.
# [I 2025-07-09 08:29:45,144] Trial 29 finished with value: 0.08141528815031052 and parameters: {'eta': 0.024139496171186443, 'max_depth': 3, 'subsample': 0.8296154206786214, 'colsample': 0.7464409913536408, 'lambda': 3.1451960757808974, 'alpha': 0.45771346073907904, 'min_child_weight': 6.248931038157133, 'n_rounds': 500}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  64%|██████▍   | 32/50 [00:04<00:02,  6.00it/s]
# [I 2025-07-09 08:29:45,281] Trial 30 finished with value: 0.08082467317581177 and parameters: {'eta': 0.04439944144662934, 'max_depth': 4, 'subsample': 0.6941165096352365, 'colsample': 0.8556806329517409, 'lambda': 4.880197125285327, 'alpha': 0.5139393593417654, 'min_child_weight': 5.905607663520212, 'n_rounds': 1000}. Best is trial 25 with value: 0.07925194501876831.
# [I 2025-07-09 08:29:45,475] Trial 31 finished with value: 0.0802752822637558 and parameters: {'eta': 0.02971942746060576, 'max_depth': 4, 'subsample': 0.7337060289338352, 'colsample': 0.885021830949608, 'lambda': 9.01557533017353, 'alpha': 0.7188413287796362, 'min_child_weight': 6.7927506382213565, 'n_rounds': 500}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  66%|██████▌   | 33/50 [00:04<00:02,  5.85it/s]
# [I 2025-07-09 08:29:45,655] Trial 32 finished with value: 0.08040844649076462 and parameters: {'eta': 0.032557873015186714, 'max_depth': 4, 'subsample': 0.774868096153666, 'colsample': 0.8939997192700655, 'lambda': 7.9423936562988775, 'alpha': 0.6955699159186521, 'min_child_weight': 6.429637447991312, 'n_rounds': 500}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  70%|███████   | 35/50 [00:04<00:02,  5.42it/s]
# [I 2025-07-09 08:29:45,865] Trial 33 finished with value: 0.08022627234458923 and parameters: {'eta': 0.023546876676157517, 'max_depth': 4, 'subsample': 0.7286137844606922, 'colsample': 0.8563965501460422, 'lambda': 5.672662650625023, 'alpha': 0.631155849137876, 'min_child_weight': 5.738774450240624, 'n_rounds': 500}. Best is trial 25 with value: 0.07925194501876831.
# [I 2025-07-09 08:29:46,055] Trial 34 finished with value: 0.08035387843847275 and parameters: {'eta': 0.04190797891240844, 'max_depth': 4, 'subsample': 0.797475865778323, 'colsample': 0.897559355381346, 'lambda': 9.940037541559382, 'alpha': 0.5112609742382079, 'min_child_weight': 7.378325390199631, 'n_rounds': 1000}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  72%|███████▏  | 36/50 [00:05<00:02,  4.97it/s]
# [I 2025-07-09 08:29:46,295] Trial 35 finished with value: 0.08047270774841309 and parameters: {'eta': 0.02011792355134213, 'max_depth': 4, 'subsample': 0.6784014371923172, 'colsample': 0.8651716485824025, 'lambda': 6.400917794616473, 'alpha': 0.8085480226910438, 'min_child_weight': 5.468162517725965, 'n_rounds': 1000}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  74%|███████▍  | 37/50 [00:05<00:02,  4.86it/s]
# [I 2025-07-09 08:29:46,511] Trial 36 finished with value: 0.0809851735830307 and parameters: {'eta': 0.03363551042756449, 'max_depth': 3, 'subsample': 0.758746716912463, 'colsample': 0.8205421247838508, 'lambda': 4.438145569527506, 'alpha': 0.3893376293240953, 'min_child_weight': 6.872505549438506, 'n_rounds': 500}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  78%|███████▊  | 39/50 [00:05<00:02,  4.97it/s]
# [I 2025-07-09 08:29:46,717] Trial 37 finished with value: 0.08008456975221634 and parameters: {'eta': 0.029607619427029858, 'max_depth': 4, 'subsample': 0.856106444794952, 'colsample': 0.7655646862422483, 'lambda': 7.556261329565114, 'alpha': 0.7668074692615575, 'min_child_weight': 6.187799373655961, 'n_rounds': 500}. Best is trial 25 with value: 0.07925194501876831.
# [I 2025-07-09 08:29:46,907] Trial 38 finished with value: 0.07974528521299362 and parameters: {'eta': 0.02494412986507111, 'max_depth': 4, 'subsample': 0.6897456889244715, 'colsample': 0.8364882071336854, 'lambda': 3.3030815662650004, 'alpha': 0.4029383752595383, 'min_child_weight': 7.369003163836495, 'n_rounds': 1000}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  82%|████████▏ | 41/50 [00:06<00:01,  5.35it/s]
# [I 2025-07-09 08:29:47,120] Trial 39 finished with value: 0.08104944974184036 and parameters: {'eta': 0.02363009849232821, 'max_depth': 3, 'subsample': 0.6975651575436143, 'colsample': 0.7122515054468874, 'lambda': 3.2244366655418477, 'alpha': 0.4102741433056465, 'min_child_weight': 7.444511128905518, 'n_rounds': 1000}. Best is trial 25 with value: 0.07925194501876831.
# [I 2025-07-09 08:29:47,265] Trial 40 finished with value: 0.07950955629348755 and parameters: {'eta': 0.05278710079846049, 'max_depth': 4, 'subsample': 0.6707299977013632, 'colsample': 0.8227203592612152, 'lambda': 5.316257468545712, 'alpha': 0.476912600302032, 'min_child_weight': 7.069587713479224, 'n_rounds': 1000}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  86%|████████▌ | 43/50 [00:06<00:01,  6.59it/s]
# [I 2025-07-09 08:29:47,348] Trial 41 finished with value: 0.08437607437372208 and parameters: {'eta': 0.14983034549705676, 'max_depth': 4, 'subsample': 0.675521338921366, 'colsample': 0.8335131083314504, 'lambda': 5.396253522935099, 'alpha': 0.4534185500470552, 'min_child_weight': 7.082237363041381, 'n_rounds': 1000}. Best is trial 25 with value: 0.07925194501876831.
# [I 2025-07-09 08:29:47,487] Trial 42 finished with value: 0.08188137412071228 and parameters: {'eta': 0.06655923700067433, 'max_depth': 4, 'subsample': 0.6667683743919738, 'colsample': 0.8033281251449831, 'lambda': 4.532686779578227, 'alpha': 0.5481215892225584, 'min_child_weight': 7.006803079240456, 'n_rounds': 1500}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  90%|█████████ | 45/50 [00:06<00:00,  6.39it/s]
# [I 2025-07-09 08:29:47,633] Trial 43 finished with value: 0.08062339574098587 and parameters: {'eta': 0.054498754166575084, 'max_depth': 4, 'subsample': 0.7210994813635531, 'colsample': 0.8333731158044326, 'lambda': 3.1728414979753166, 'alpha': 0.39662499657174255, 'min_child_weight': 7.228037697025575, 'n_rounds': 1000}. Best is trial 25 with value: 0.07925194501876831.
# [I 2025-07-09 08:29:47,807] Trial 44 finished with value: 0.08071387559175491 and parameters: {'eta': 0.025699519906591427, 'max_depth': 4, 'subsample': 0.5931743982873512, 'colsample': 0.787385055722915, 'lambda': 6.047329717379677, 'alpha': 0.4777877265479652, 'min_child_weight': 8.247599749381717, 'n_rounds': 500}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  94%|█████████▍| 47/50 [00:07<00:00,  6.18it/s]
# [I 2025-07-09 08:29:48,006] Trial 45 finished with value: 0.0805630087852478 and parameters: {'eta': 0.02239436553416706, 'max_depth': 4, 'subsample': 0.6253181795989089, 'colsample': 0.8671483195838008, 'lambda': 2.2717007490224277, 'alpha': 0.2379468484930254, 'min_child_weight': 6.382522214203619, 'n_rounds': 1500}. Best is trial 25 with value: 0.07925194501876831.
# [I 2025-07-09 08:29:48,152] Trial 46 finished with value: 0.08069349825382233 and parameters: {'eta': 0.03511965734953512, 'max_depth': 3, 'subsample': 0.6591312037163314, 'colsample': 0.7684982384377842, 'lambda': 4.177281175086334, 'alpha': 0.64922150553324, 'min_child_weight': 6.944097874830098, 'n_rounds': 1000}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519:  98%|█████████▊| 49/50 [00:07<00:00,  6.58it/s]
# [I 2025-07-09 08:29:48,335] Trial 47 finished with value: 0.08051557093858719 and parameters: {'eta': 0.027516805202940715, 'max_depth': 4, 'subsample': 0.6950249870222444, 'colsample': 0.7241914306538179, 'lambda': 5.100793070965508, 'alpha': 0.37089038715649425, 'min_child_weight': 5.998590523591597, 'n_rounds': 500}. Best is trial 25 with value: 0.07925194501876831.
# [I 2025-07-09 08:29:48,448] Trial 48 finished with value: 0.08310826867818832 and parameters: {'eta': 0.06244893557230148, 'max_depth': 4, 'subsample': 0.6091809522650633, 'colsample': 0.8165428313604297, 'lambda': 2.9369905737869075, 'alpha': 0.5466821800315367, 'min_child_weight': 7.512745364504762, 'n_rounds': 1500}. Best is trial 25 with value: 0.07925194501876831.
# Best trial: 25. Best value: 0.0792519: 100%|██████████| 50/50 [00:07<00:00,  6.67it/s]
# [I 2025-07-09 08:29:48,575] Trial 49 finished with value: 0.0837634950876236 and parameters: {'eta': 0.0410646764142965, 'max_depth': 1, 'subsample': 0.702894864471988, 'colsample': 0.49024956474588455, 'lambda': 2.3238597563863754, 'alpha': 0.4334708316258629, 'min_child_weight': 6.587613532241641, 'n_rounds': 500}. Best is trial 25 with value: 0.07925194501876831.

# %%
preds_te_std2 = booster.predict(dtest)
preds_tr_std2 = booster.predict(dtrain)

y_te_inv2  = sc_y.inverse_transform(y_te)
y_tr_inv2  = sc_y.inverse_transform(y_tr)
preds_te2  = sc_y.inverse_transform(np.array(preds_te_std2).reshape(-1, 1))
preds_tr2  = sc_y.inverse_transform(np.array(preds_tr_std2).reshape(-1, 1))

print("R² test :", r2_score(y_te_inv2, preds_te2))
print("RMSE test:", mean_squared_error(y_te_inv2, preds_te2, squared=False))
print("R² train:", r2_score(y_tr_inv2, preds_tr2))
print("RMSE train:", mean_squared_error(y_tr_inv2, preds_tr2, squared=False))
# Out:
# R² test : 0.08803552389144897
# RMSE test: 4.088847
# R² train: 0.35936135053634644
# RMSE train: 3.4021928

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Predictions")
plt.scatter(y_tr_inv2,preds_tr2,label="Train")
plt.scatter(y_te_inv2,preds_te2,label="Test")
plt.legend()
plt.subplot(122)
plt.title("Resisuals")
plt.scatter(y_tr_inv2,preds_tr2-y_tr_inv2,label="Train")
plt.scatter(y_te_inv2,preds_te2-y_te_inv2,label="Test")
plt.legend()
plt.show()

# %%
booster

# %%
import numpy as np, matplotlib.pyplot as plt, xgboost as xgb, torch
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from typing import Any

# ═══════════════════════════════════════════════════════════════════
# 1. Wrappers: dan predict() y un fit() vacío (requisito sklearn)
# ═══════════════════════════════════════════════════════════════════
class TorchRegressorWrapper:
    def __init__(self, model: torch.nn.Module, scaler_y):
        self.model = model.eval().to(next(model.parameters()).device)
        self.scaler_y = scaler_y
    def fit(self, X: Any, y: Any):     # <- para que sklearn no proteste
        return self
    def predict(self, X):
        X_t = torch.tensor(X, dtype=torch.float32, device=next(self.model.parameters()).device)
        with torch.no_grad():
            y_hat_std = self.model(X_t).cpu().numpy()
        return self.scaler_y.inverse_transform(y_hat_std).ravel()

class XGBRegressorWrapper:
    def __init__(self, booster: xgb.Booster):
        self.bst = booster
    def fit(self, X: Any, y: Any):
        return self
    def predict(self, X):
        return self.bst.predict(xgb.DMatrix(X))

mlp_wrap = TorchRegressorWrapper(best_model, sc_y)
xgb_wrap = XGBRegressorWrapper(booster)

# ═══════════════════════════════════════════════════════════════════
# 2. Conjuntos para permutar
#    · MLP → entradas estandarizadas
#    · XGB → sin escalar
# ═══════════════════════════════════════════════════════════════════
X_te_std = sc_x.transform(X_te)        # estándar usado en entrenamiento MLP

# ═══════════════════════════════════════════════════════════════════
# 3. Permutation Feature Importance
# ═══════════════════════════════════════════════════════════════════
def pfi(estimator, X, y):
    return permutation_importance(
        estimator, X, y,
        n_repeats=50,
        scoring="neg_root_mean_squared_error",
        random_state=rs,
        n_jobs=-1)

pi_mlp = pfi(mlp_wrap, X_te, y_te)
pi_xgb = pfi(xgb_wrap, X_te, y_te)

# %%
feat_names = data.drop(columns=[var]).columns
len(feat_names)
# Out:
# 15

# %%
sumi=pd.DataFrame({"Features":feat_names,
                   "Importances Mean (MLP)":pi_mlp.importances_mean, 
                   "Importances Std (MLP)":pi_mlp.importances_std,
                  "Importances Mean (XB)":pi_xgb.importances_mean, 
                   "Importances Std (XB)":pi_xgb.importances_std})

# %%
# ═══════════════════════════════════════════════════════════════════
# 4. Plot boxplots lado a lado
# ═══════════════════════════════════════════════════════════════════
def plot_box(ax, result, title):
    order = np.argsort(result.importances_mean)[::-1]
    ax.boxplot(result.importances.T[:, order], vert=False,
               labels=feat_names[order])
    ax.axvline(0, color="k", ls="--")
    ax.set_title(title)
    ax.set_xlabel("Decrease in RMSE (perm−base)")

fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharex=False, sharey=False)
plot_box(axes[0], pi_mlp, "Permutation Importance – MLP")
plot_box(axes[1], pi_xgb, "Permutation Importance – XGBoost")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Permutation Importance – MLP")
plt.boxplot(pi_mlp.importances.T[:, np.argsort(pi_mlp.importances_mean)[::-1]]*1, vert=False,
               labels=feat_names[np.argsort(pi_mlp.importances_mean)[::-1]], medianprops=dict(color='red'), 
            patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.axvline(0, color="k", ls="--"); plt.grid(alpha=0.3)
plt.subplot(122)
plt.title("Permutation Importance – XGBoost")
plt.boxplot(np.log10(pi_xgb.importances.T[:, np.argsort(pi_xgb.importances_mean)[::-1]]*150), vert=False,
               labels=feat_names[np.argsort(pi_xgb.importances_mean)[::-1]], medianprops=dict(color='red'), 
            patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.axvline(0, color="k", ls="--"); plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
data[var].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()

# %%
data["Lempel-Ziv Complexity"].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()

# %%
data["Shannon Entropy"].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()

# %%
data["Katz Fractal Dim."].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()

# %%
data["Higuchi Fractal Dim."].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()

# %%
data["Permutation Entropy"].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()

# %%
data["Approximate Entropy"].plot(figsize=(16,2)); plt.legend(); plt.grid(alpha=0.3); plt.show()
