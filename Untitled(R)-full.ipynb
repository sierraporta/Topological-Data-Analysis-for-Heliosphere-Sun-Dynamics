# %% [markdown]
# # Results.....

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import root_mean_squared_error, r2_score, mean_absolute_percentage_error
import scienceplots
plt.style.use(["science","nature"])
plt.rcParams.update({"font.size": 12,
                    "xtick.labelsize": 12,
                    "ytick.labelsize": 12,
                    "axes.labelsize": 12,
                    'legend.fontsize': 12})
import warnings
# Ignore all warnings
warnings.filterwarnings("ignore")
rs=142
tsize=.35

# %%
var="R"
#data = pd.read_csv("datas/dataforR_all.csv",index_col=0)
data = pd.read_csv("datas/dataforR_all.csv",index_col=0)
#data = pd.read_csv("datas/dataforR_all.csv",index_col=0)
data=data[data.index>="1964-08"].dropna() # Only cycle 20 to 25
data=data.rename(columns={"R (Sunspot)":"R",
                          "f10.7_index":"F10.7",
                          "Dst-index":"Dst",
                          "Scalar B, nT":"B |IMF|",
                          "SW Plasma Temperature, K":"sw Temperature",
                          "SW Proton Density, N/cm^3":"sw Density",
                          "SW Plasma Speed, km/s":"sw Speed",
                          "Alpha/Prot. ratio":"Alpha/Proton ratio"})
print(len(data))
data=data[(data[var]>0)&(data[var]<300)]
print(len(data))
# Out:
# 21917
# 19066

# %%
data
# Out:
#             Shannon Entropy  Sample Entropy  Permutation Entropy  \
# 1964-10-02         1.621382        0.939280             0.915260
# 1964-10-06         1.606807        0.957299             0.926698
# 1964-10-07         1.611630        0.974998             0.919452
# 1964-10-08         1.600308        0.960742             0.924322
# 1964-10-09         1.588894        0.955511             0.926522
# ...                     ...             ...                  ...
# 2024-09-27         1.784296        1.213023             0.969271
# 2024-09-28         1.868829        1.213023             0.973332
# 2024-09-29         1.875078        1.386294             0.976920
# 2024-09-30         1.885347        1.386294             0.979939
# 2024-10-01         1.904594        1.386294             0.982272
#
#             Spectral Entropy  Approximate Entropy  Higuchi Fractal Dim.  \
# 1964-10-02          0.872979             0.527596              1.974110
# 1964-10-06          0.885306             0.560094              1.959589
# 1964-10-07          0.876492             0.575306              1.960289
# 1964-10-08          0.876720             0.574106              1.952110
# 1964-10-09          0.864771             0.603913              1.948175
# ...                      ...                  ...                   ...
# 2024-09-27          0.447702             0.425367              1.635615
# 2024-09-28          0.442246             0.433296              1.655558
# 2024-09-29          0.442888             0.430874              1.670411
# 2024-09-30          0.439470             0.439238              1.676212
# 2024-10-01          0.442920             0.447933              1.669696
#
#             Katz Fractal Dim.  Petrosian Fractal Dim.  Lempel-Ziv Complexity  \
# 1964-10-02           2.760455                1.047711                   25.0
# 1964-10-06           2.948713                1.046835                   27.0
# 1964-10-07           2.934866                1.045817                   28.0
# 1964-10-08           2.994318                1.046431                   28.0
# 1964-10-09           2.968402                1.047013                   28.0
# ...                       ...                     ...                    ...
# 2024-09-27           1.499093                1.046835                   49.0
# 2024-09-28           1.554027                1.047895                   48.0
# 2024-09-29           1.599928                1.049001                   47.0
# 2024-09-30           1.621512                1.050155                   46.0
# 2024-10-01           1.684741                1.051361                   45.0
#
#             Hurst Exponent      R  B |IMF|  sw Temperature  sw Density  \
# 1964-10-02        0.000000   18.0    4.251        72313.56       6.465
# 1964-10-06        0.000000   21.0    5.290       202687.44       2.645
# 1964-10-07        0.000000   29.0    4.867       144091.54       4.827
# 1964-10-08        0.000000   24.0    5.812       114111.58       5.122
# 1964-10-09        2.424129   17.0    5.621       129730.38       5.652
# ...                    ...    ...      ...             ...         ...
# 2024-09-27        0.000000  154.0    5.500        43700.00       6.600
# 2024-09-28        0.000000  154.0    5.900        45245.00       8.400
# 2024-09-29        0.000000  149.0    9.200       138847.00      12.100
# 2024-09-30        0.000000  169.0    8.300       147140.00       3.600
# 2024-10-01        0.000000  212.0    6.200        93912.00       3.400
#
#             sw Speed  Alpha/Proton ratio
# 1964-10-02     405.0               0.000
# 1964-10-06     679.0               0.000
# 1964-10-07     543.0               0.000
# 1964-10-08     503.0               0.000
# 1964-10-09     490.0               0.000
# ...              ...                 ...
# 2024-09-27     341.0               0.042
# 2024-09-28     312.0               0.041
# 2024-09-29     364.0               0.067
# 2024-09-30     443.0               0.048
# 2024-10-01     417.0               0.055
#
# [19066 rows x 16 columns]

# %%
#from sklearn.preprocessing import StandardScaler, QuantileTransformer
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import mean_squared_error, r2_score
# ─────────────────────────────────────────────
# 1. Pre-procesamiento
# ─────────────────────────────────────────────
#X = data.drop(columns=[var]).values
#y = data[var].values.reshape(-1, 1)

#sc_x, sc_y = StandardScaler(), StandardScaler()
#X_std = sc_x.fit_transform(X).astype(np.float32)
#y_std = sc_y.fit_transform(y).astype(np.float32)
#sc_x, sc_y = QuantileTransformer(random_state=rs), QuantileTransformer(random_state=rs)
#X_std = sc_x.fit_transform(X).astype(np.float32)
#y_std = sc_y.fit_transform(y).astype(np.float32)

#X_tr, X_te, y_tr, y_te = train_test_split(X_std, 
#                                          y_std, 
#                                          test_size=tsize, 
#                                          random_state=rs)

# %%
#pd.DataFrame(y_tr).describe()[0].values

# %%
#pd.DataFrame({"Full original":pd.DataFrame(y).describe()[0].values,
#             "Test scaled":pd.DataFrame(y_te).describe()[0].values,
#             "Train scaled":pd.DataFrame(y_tr).describe()[0].values},
#             index=pd.DataFrame(y_tr).describe().index)

# %%
#plt.figure(figsize=(16,4))
#plt.subplot(131)
#plt.hist(y,bins=50,label="Original"); plt.legend()
#plt.subplot(132)
#plt.hist(y_std,bins=50,label="Transform"); plt.legend()
#plt.subplot(133)
#plt.plot(y_std,label="Time series"); plt.legend()
#plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(16,5))
sns.heatmap(data.corr(), annot=True, cmap="jet")
plt.xticks(rotation=30,ha="right")
plt.tight_layout()
plt.savefig("figures/Correlations_R_local.pdf",bbox_inches='tight',dpi=300)
plt.show()

# %%
data.columns
# Out:
# Index(['Shannon Entropy', 'Sample Entropy', 'Permutation Entropy',
#        'Spectral Entropy', 'Approximate Entropy', 'Higuchi Fractal Dim.',
#        'Katz Fractal Dim.', 'Petrosian Fractal Dim.', 'Lempel-Ziv Complexity',
#        'Hurst Exponent', 'R', 'B |IMF|', 'sw Temperature', 'sw Density',
#        'sw Speed', 'Alpha/Proton ratio'],
#       dtype='object')

# %%
#data=data.drop(columns=['Sample Entropy','Permutation Entropy',"Approximate Entropy","Petrosian Fractal Dim."])

# %%
from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
# ─────────────────────────────────────────────
# 1. Pre-procesamiento
# ─────────────────────────────────────────────
X = data.drop(columns=[var]).values
y = data[var].values.reshape(-1, 1)

#sc_x, sc_y = StandardScaler(), StandardScaler()
#X_std = sc_x.fit_transform(X).astype(np.float32)
#y_std = sc_y.fit_transform(y).astype(np.float32)
sc_x, sc_y = QuantileTransformer(random_state=rs), QuantileTransformer(random_state=rs)
X_std = sc_x.fit_transform(X).astype(np.float32)
y_std = sc_y.fit_transform(y).astype(np.float32)

X_tr, X_te, y_tr, y_te = train_test_split(X_std, 
                                          y_std, 
                                          test_size=tsize, 
                                          random_state=rs)

# %%
pd.DataFrame({"Full original":pd.DataFrame(y).describe()[0].values,
             "Test scaled":pd.DataFrame(y_te).describe()[0].values,
             "Train scaled":pd.DataFrame(y_tr).describe()[0].values},
             index=pd.DataFrame(y_tr).describe().index)
# Out:
#        Full original  Test scaled  Train scaled
# count   19066.000000  6674.000000  12392.000000
# mean       94.590528     0.498397      0.501549
# std        69.068921     0.288502      0.290461
# min         1.000000     0.000000      0.000000
# 25%        34.000000     0.245245      0.250751
# 50%        81.000000     0.498498      0.503504
# 75%       141.000000     0.743744      0.757758
# max       299.000000     1.000000      1.000000

# %% [markdown]
# # 1 | Multiple Layer Perceptron - GPU

# %%
# ================================================================
#  MLP con PyTorch + Optuna para búsqueda de hiper-parámetros
#  Dataset: 4 602 × 14   ‒ Target: R
#  CUDA se usa si está disponible (MX250)
#  Requiere: pip install optuna torch torchvision scikit-learn
# ================================================================
import numpy as np, torch, torch.nn as nn, optuna, joblib
from torch.utils.data import TensorDataset, DataLoader

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ─────────────────────────────────────────────
# 2. Definición del modelo
# ─────────────────────────────────────────────
class MLP(nn.Module):
    def __init__(self, in_dim: int,
                 h1: int, h2: int | None, h3: int | None,
                 p_drop: float = 0.2):
        """Hasta 3 capas ocultas; las que tengan None se omiten."""
        super().__init__()
        layers = [nn.Linear(in_dim, h1), nn.ReLU(), nn.Dropout(p_drop)]
        if h2:
            layers += [nn.Linear(h1, h2), nn.ReLU(), nn.Dropout(p_drop)]
            prev = h2
        else:
            prev = h1
        if h3:
            layers += [nn.Linear(prev, h3), nn.ReLU(), nn.Dropout(p_drop)]
            prev = h3
        layers += [nn.Linear(prev, 1)]
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return self.net(x)

# ─────────────────────────────────────────────
# 3. Función de entrenamiento con early-stopping
# ─────────────────────────────────────────────
def train_mlp(params, epochs=500, patience=20):
    model = MLP(
        in_dim=X_tr.shape[1],
        h1=params['h1'],
        h2=params.get('h2'),
        h3=params.get('h3'),
        p_drop=params['dropout']).to(device)

    opt = torch.optim.Adam(
        model.parameters(),
        lr=params['lr'],
        weight_decay=params['weight_decay'])

    batch_size = params['batch']
    ds_train   = TensorDataset(torch.from_numpy(X_tr), torch.from_numpy(y_tr))
    dl_train   = DataLoader(ds_train, batch_size=batch_size, shuffle=True)

    best_val, wait = np.inf, 0
    for _ in range(epochs):
        # ── forward/backward ───────────────────────────────────
        model.train()
        for xb, yb in dl_train:
            xb, yb = xb.to(device), yb.to(device)
            opt.zero_grad()
            loss = nn.functional.mse_loss(model(xb), yb)
            loss.backward()
            opt.step()

        # ── validación rápida ─────────────────────────────────
        model.eval()
        with torch.no_grad():
            preds = model(torch.from_numpy(X_te).to(device)).cpu().numpy()
            val_loss = mean_squared_error(y_te, preds)
        # early stop
        if val_loss < best_val - 1e-4:
            best_val = val_loss
            best_state = model.state_dict()
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    model.load_state_dict(best_state)
    return model, best_val

# ─────────────────────────────────────────────
# 4. Objetivo Optuna
# ─────────────────────────────────────────────
def objective(trial: optuna.Trial) -> float:
    # muestreo de hiper-parámetros
    h1 = trial.suggest_int('h1',       32, 128, step=32)
    h2 = trial.suggest_int('h2',       16, 128, step=16)
    use_h3 = trial.suggest_categorical('use_h3', [False, True])
    h3 = trial.suggest_int('h3', 16, 64, step=16) if use_h3 else None

    params = dict(
        h1       = h1,
        h2       = h2,
        h3       = h3,
        dropout  = trial.suggest_float('dropout', 0.0, 0.4, step=0.1),
        lr       = trial.suggest_float('lr', 1e-4, 5e-3, log=True),
        weight_decay = trial.suggest_float('weight_decay', 1e-5, 1e-2, log=True),
        batch    = trial.suggest_categorical('batch', [64, 128, 256]),
    )

    # entrena y evalúa
    _, val_rmse = train_mlp(params)
    # Optuna minimiza -> devolver RMSE
    return val_rmse

# ─────────────────────────────────────────────
# 5. Ejecución del estudio
# ─────────────────────────────────────────────
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=40, timeout=None, show_progress_bar=True)

print("\n⇢  Mejor RMSE válido  :", study.best_value**0.5)   # pasa de MSE a RMSE
print("⇢  Mejores parámetros :", study.best_params)

joblib.dump(study, "optuna_mlp_study.pkl")

# ─────────────────────────────────────────────
# 6. Entrenamiento final con el mejor conjunto
# ─────────────────────────────────────────────
best_model, _ = train_mlp(study.best_params, epochs=800, patience=30)
# Out:
# [I 2025-07-11 07:45:20,208] A new study created in memory with name: no-name-e2bcc064-8438-4182-9ab2-cc93b01241c5
# Best trial: 0. Best value: 0.0298902:   2%|▎         | 1/40 [00:22<14:34, 22.43s/it]
# [I 2025-07-11 07:45:42,640] Trial 0 finished with value: 0.029890216886997223 and parameters: {'h1': 128, 'h2': 32, 'use_h3': False, 'dropout': 0.30000000000000004, 'lr': 0.002888122449284534, 'weight_decay': 5.9782914334602346e-05, 'batch': 64}. Best is trial 0 with value: 0.029890216886997223.
# Best trial: 0. Best value: 0.0298902:   5%|▌         | 2/40 [00:41<12:52, 20.32s/it]
# [I 2025-07-11 07:46:01,483] Trial 1 finished with value: 0.03258298709988594 and parameters: {'h1': 32, 'h2': 128, 'use_h3': False, 'dropout': 0.30000000000000004, 'lr': 0.0004662200451434488, 'weight_decay': 0.002866062712983576, 'batch': 64}. Best is trial 0 with value: 0.029890216886997223.
# Best trial: 0. Best value: 0.0298902:   8%|▊         | 3/40 [00:48<08:55, 14.46s/it]
# [I 2025-07-11 07:46:08,973] Trial 2 finished with value: 0.03374343737959862 and parameters: {'h1': 32, 'h2': 64, 'use_h3': True, 'h3': 32, 'dropout': 0.4, 'lr': 0.002642054854393098, 'weight_decay': 0.0037996634500785213, 'batch': 128}. Best is trial 0 with value: 0.029890216886997223.
# Best trial: 0. Best value: 0.0298902:  10%|█         | 4/40 [00:56<07:07, 11.87s/it]
# [I 2025-07-11 07:46:16,876] Trial 3 finished with value: 0.033473338931798935 and parameters: {'h1': 96, 'h2': 80, 'use_h3': False, 'dropout': 0.2, 'lr': 0.0010768758954018767, 'weight_decay': 0.005149111214672567, 'batch': 128}. Best is trial 0 with value: 0.029890216886997223.
# Best trial: 0. Best value: 0.0298902:  12%|█▎        | 5/40 [01:42<14:05, 24.16s/it]
# [I 2025-07-11 07:47:02,825] Trial 4 finished with value: 0.029921703040599823 and parameters: {'h1': 32, 'h2': 128, 'use_h3': True, 'h3': 48, 'dropout': 0.0, 'lr': 0.0015955719049058233, 'weight_decay': 0.0003996799932380438, 'batch': 64}. Best is trial 0 with value: 0.029890216886997223.
# Best trial: 5. Best value: 0.027548:  15%|█▌        | 6/40 [02:05<13:30, 23.84s/it]
# [I 2025-07-11 07:47:26,045] Trial 5 finished with value: 0.02754799835383892 and parameters: {'h1': 96, 'h2': 32, 'use_h3': False, 'dropout': 0.0, 'lr': 0.0017958344533492482, 'weight_decay': 7.912801840833031e-05, 'batch': 256}. Best is trial 5 with value: 0.02754799835383892.
# Best trial: 5. Best value: 0.027548:  18%|█▊        | 7/40 [02:22<11:48, 21.46s/it]
# [I 2025-07-11 07:47:42,604] Trial 6 finished with value: 0.03445048630237579 and parameters: {'h1': 96, 'h2': 64, 'use_h3': True, 'h3': 48, 'dropout': 0.0, 'lr': 0.0002618766635236396, 'weight_decay': 0.009643650254300265, 'batch': 64}. Best is trial 5 with value: 0.02754799835383892.
# Best trial: 5. Best value: 0.027548:  20%|██        | 8/40 [03:03<14:42, 27.59s/it]
# [I 2025-07-11 07:48:23,314] Trial 7 finished with value: 0.029314061626791954 and parameters: {'h1': 96, 'h2': 128, 'use_h3': True, 'h3': 32, 'dropout': 0.30000000000000004, 'lr': 0.001047714891938027, 'weight_decay': 0.00016755080442181863, 'batch': 256}. Best is trial 5 with value: 0.02754799835383892.
# Best trial: 8. Best value: 0.0265114:  22%|██▎       | 9/40 [05:53<37:16, 72.16s/it]
# [I 2025-07-11 07:51:13,474] Trial 8 finished with value: 0.026511428877711296 and parameters: {'h1': 128, 'h2': 48, 'use_h3': True, 'h3': 32, 'dropout': 0.2, 'lr': 0.0001767472500072783, 'weight_decay': 0.00015169527505220015, 'batch': 64}. Best is trial 8 with value: 0.026511428877711296.
# Best trial: 8. Best value: 0.0265114:  25%|██▌       | 10/40 [08:11<46:17, 92.58s/it]
# [I 2025-07-11 07:53:31,788] Trial 9 finished with value: 0.027895130217075348 and parameters: {'h1': 64, 'h2': 48, 'use_h3': True, 'h3': 32, 'dropout': 0.1, 'lr': 0.00011526771838651624, 'weight_decay': 2.606409008358196e-05, 'batch': 64}. Best is trial 8 with value: 0.026511428877711296.
# Best trial: 8. Best value: 0.0265114:  28%|██▊       | 11/40 [09:30<42:41, 88.33s/it]
# [I 2025-07-11 07:54:50,468] Trial 10 finished with value: 0.031142817810177803 and parameters: {'h1': 128, 'h2': 96, 'use_h3': True, 'h3': 16, 'dropout': 0.2, 'lr': 0.0001012309738599127, 'weight_decay': 0.0006706736288020053, 'batch': 128}. Best is trial 8 with value: 0.026511428877711296.
# Best trial: 8. Best value: 0.0265114:  30%|███       | 12/40 [10:10<34:25, 73.75s/it]
# [I 2025-07-11 07:55:30,880] Trial 11 finished with value: 0.02799363248050213 and parameters: {'h1': 128, 'h2': 16, 'use_h3': False, 'dropout': 0.1, 'lr': 0.00044234521542547446, 'weight_decay': 1.044000281089842e-05, 'batch': 256}. Best is trial 8 with value: 0.026511428877711296.
# Best trial: 8. Best value: 0.0265114:  32%|███▎      | 13/40 [10:39<27:07, 60.29s/it]
# [I 2025-07-11 07:56:00,180] Trial 12 finished with value: 0.030239518731832504 and parameters: {'h1': 64, 'h2': 16, 'use_h3': False, 'dropout': 0.1, 'lr': 0.0002628429223457321, 'weight_decay': 0.00010770725222880398, 'batch': 256}. Best is trial 8 with value: 0.026511428877711296.
# Best trial: 8. Best value: 0.0265114:  35%|███▌      | 14/40 [10:58<20:40, 47.70s/it]
# [I 2025-07-11 07:56:18,796] Trial 13 finished with value: 0.030605992302298546 and parameters: {'h1': 128, 'h2': 48, 'use_h3': False, 'dropout': 0.0, 'lr': 0.004596230076420866, 'weight_decay': 0.0006566775038070622, 'batch': 256}. Best is trial 8 with value: 0.026511428877711296.
# Best trial: 8. Best value: 0.0265114:  38%|███▊      | 15/40 [11:23<16:57, 40.72s/it]
# [I 2025-07-11 07:56:43,339] Trial 14 finished with value: 0.031577643007040024 and parameters: {'h1': 96, 'h2': 32, 'use_h3': True, 'h3': 64, 'dropout': 0.4, 'lr': 0.00020865210491360526, 'weight_decay': 3.9060690097747246e-05, 'batch': 256}. Best is trial 8 with value: 0.026511428877711296.
# Best trial: 8. Best value: 0.0265114:  40%|████      | 16/40 [12:28<19:14, 48.10s/it]
# [I 2025-07-11 07:57:48,567] Trial 15 finished with value: 0.028759131208062172 and parameters: {'h1': 64, 'h2': 48, 'use_h3': False, 'dropout': 0.1, 'lr': 0.0007987931631816748, 'weight_decay': 0.00023549379752543494, 'batch': 64}. Best is trial 8 with value: 0.026511428877711296.
# Best trial: 16. Best value: 0.026021:  42%|████▎     | 17/40 [13:27<19:43, 51.45s/it]
# [I 2025-07-11 07:58:47,827] Trial 16 finished with value: 0.026021040976047516 and parameters: {'h1': 128, 'h2': 96, 'use_h3': True, 'h3': 16, 'dropout': 0.2, 'lr': 0.001710577913687359, 'weight_decay': 8.516393009864133e-05, 'batch': 256}. Best is trial 16 with value: 0.026021040976047516.
# Best trial: 16. Best value: 0.026021:  45%|████▌     | 18/40 [13:54<16:12, 44.21s/it]
# [I 2025-07-11 07:59:15,163] Trial 17 finished with value: 0.03237241134047508 and parameters: {'h1': 128, 'h2': 96, 'use_h3': True, 'h3': 16, 'dropout': 0.2, 'lr': 0.0004907840073069315, 'weight_decay': 0.0014642612402878204, 'batch': 64}. Best is trial 16 with value: 0.026021040976047516.
# Best trial: 18. Best value: 0.0253762:  48%|████▊     | 19/40 [15:46<22:33, 64.46s/it]
# [I 2025-07-11 08:01:06,800] Trial 18 finished with value: 0.025376232340931892 and parameters: {'h1': 128, 'h2': 80, 'use_h3': True, 'h3': 16, 'dropout': 0.2, 'lr': 0.00020183172276944328, 'weight_decay': 1.9142601815957292e-05, 'batch': 256}. Best is trial 18 with value: 0.025376232340931892.
# Best trial: 18. Best value: 0.0253762:  50%|█████     | 20/40 [16:14<17:51, 53.55s/it]
# [I 2025-07-11 08:01:34,935] Trial 19 finished with value: 0.028864964842796326 and parameters: {'h1': 128, 'h2': 96, 'use_h3': True, 'h3': 16, 'dropout': 0.30000000000000004, 'lr': 0.0047832878761035124, 'weight_decay': 1.6647110905479253e-05, 'batch': 256}. Best is trial 18 with value: 0.025376232340931892.
# Best trial: 20. Best value: 0.0247172:  52%|█████▎    | 21/40 [17:18<17:57, 56.71s/it]
# [I 2025-07-11 08:02:39,000] Trial 20 finished with value: 0.024717189371585846 and parameters: {'h1': 96, 'h2': 112, 'use_h3': True, 'h3': 16, 'dropout': 0.2, 'lr': 0.0007187988193998232, 'weight_decay': 2.9284210798130504e-05, 'batch': 256}. Best is trial 20 with value: 0.024717189371585846.
# Best trial: 20. Best value: 0.0247172:  55%|█████▌    | 22/40 [18:13<16:51, 56.20s/it]
# [I 2025-07-11 08:03:34,019] Trial 21 finished with value: 0.02542799711227417 and parameters: {'h1': 96, 'h2': 112, 'use_h3': True, 'h3': 16, 'dropout': 0.2, 'lr': 0.0007244457988093394, 'weight_decay': 3.505095047336158e-05, 'batch': 256}. Best is trial 20 with value: 0.024717189371585846.
# Best trial: 20. Best value: 0.0247172:  57%|█████▊    | 23/40 [19:18<16:36, 58.61s/it]
# [I 2025-07-11 08:04:38,246] Trial 22 finished with value: 0.025110114365816116 and parameters: {'h1': 96, 'h2': 112, 'use_h3': True, 'h3': 16, 'dropout': 0.2, 'lr': 0.0007338077203565998, 'weight_decay': 2.9878664381851445e-05, 'batch': 256}. Best is trial 20 with value: 0.024717189371585846.
# Best trial: 20. Best value: 0.0247172:  60%|██████    | 24/40 [19:39<12:41, 47.56s/it]
# [I 2025-07-11 08:05:00,043] Trial 23 finished with value: 0.03219243139028549 and parameters: {'h1': 64, 'h2': 112, 'use_h3': True, 'h3': 16, 'dropout': 0.30000000000000004, 'lr': 0.0003534475413942905, 'weight_decay': 1.1038860659995129e-05, 'batch': 256}. Best is trial 20 with value: 0.024717189371585846.
# [I 2025-07-11 08:14:31,454] Trial 31 finished with value: 0.024146361276507378 and parameters: {'h1': 96, 'h2': 112, 'use_h3': True, 'h3': 32, 'dropout': 0.1, 'lr': 0.0005326550774269321, 'weight_decay': 4.982123611743201e-05, 'batch': 128}. Best is trial 27 with value: 0.023926889523863792.
# Best trial: 27. Best value: 0.0239269:  82%|████████▎ | 33/40 [30:10<07:57, 68.23s/it]
# [I 2025-07-11 08:15:30,391] Trial 32 finished with value: 0.02458972856402397 and parameters: {'h1': 96, 'h2': 112, 'use_h3': True, 'h3': 32, 'dropout': 0.1, 'lr': 0.0009918975900526596, 'weight_decay': 5.104640095716875e-05, 'batch': 128}. Best is trial 27 with value: 0.023926889523863792.
# Best trial: 27. Best value: 0.0239269:  85%|████████▌ | 34/40 [31:07<06:29, 64.96s/it]
# [I 2025-07-11 08:16:27,728] Trial 33 finished with value: 0.029231298714876175 and parameters: {'h1': 32, 'h2': 128, 'use_h3': True, 'h3': 32, 'dropout': 0.1, 'lr': 0.0005460461526213327, 'weight_decay': 0.00024265499827364577, 'batch': 128}. Best is trial 27 with value: 0.023926889523863792.
# Best trial: 27. Best value: 0.0239269:  88%|████████▊ | 35/40 [32:49<06:20, 76.18s/it]
# [I 2025-07-11 08:18:10,071] Trial 34 finished with value: 0.024638256058096886 and parameters: {'h1': 96, 'h2': 96, 'use_h3': True, 'h3': 48, 'dropout': 0.1, 'lr': 0.00035892946716748175, 'weight_decay': 7.70346003040136e-05, 'batch': 128}. Best is trial 27 with value: 0.023926889523863792.
# Best trial: 27. Best value: 0.0239269:  90%|█████████ | 36/40 [33:36<04:28, 67.24s/it]
# [I 2025-07-11 08:18:56,443] Trial 35 finished with value: 0.026443881914019585 and parameters: {'h1': 64, 'h2': 128, 'use_h3': True, 'h3': 32, 'dropout': 0.0, 'lr': 0.0009143906127091539, 'weight_decay': 4.763533653225852e-05, 'batch': 128}. Best is trial 27 with value: 0.023926889523863792.
# Best trial: 27. Best value: 0.0239269:  92%|█████████▎| 37/40 [34:14<02:55, 58.56s/it]
# [I 2025-07-11 08:19:34,760] Trial 36 finished with value: 0.02728915587067604 and parameters: {'h1': 96, 'h2': 112, 'use_h3': True, 'h3': 32, 'dropout': 0.1, 'lr': 0.0014655203263838103, 'weight_decay': 9.649353721447576e-05, 'batch': 128}. Best is trial 27 with value: 0.023926889523863792.
# Best trial: 27. Best value: 0.0239269:  95%|█████████▌| 38/40 [34:33<01:33, 46.73s/it]
# [I 2025-07-11 08:19:53,871] Trial 37 finished with value: 0.027532503008842468 and parameters: {'h1': 32, 'h2': 128, 'use_h3': False, 'dropout': 0.0, 'lr': 0.003093851532882026, 'weight_decay': 1.543084944285633e-05, 'batch': 128}. Best is trial 27 with value: 0.023926889523863792.
# Best trial: 27. Best value: 0.0239269:  98%|█████████▊| 39/40 [35:46<00:54, 54.54s/it]
# [I 2025-07-11 08:21:06,653] Trial 38 finished with value: 0.029321113601326942 and parameters: {'h1': 96, 'h2': 96, 'use_h3': True, 'h3': 48, 'dropout': 0.1, 'lr': 0.00041480281314994736, 'weight_decay': 0.0003791706939964129, 'batch': 128}. Best is trial 27 with value: 0.023926889523863792.
# Best trial: 27. Best value: 0.0239269: 100%|██████████| 40/40 [36:55<00:00, 55.38s/it]
# [I 2025-07-11 08:22:15,436] Trial 39 finished with value: 0.02665143646299839 and parameters: {'h1': 96, 'h2': 112, 'use_h3': True, 'h3': 32, 'dropout': 0.0, 'lr': 0.0005956251993234617, 'weight_decay': 0.00019126634811800919, 'batch': 128}. Best is trial 27 with value: 0.023926889523863792.
#
# ⇢  Mejor RMSE válido  : 0.15468319082519533
# ⇢  Mejores parámetros : {'h1': 64, 'h2': 128, 'use_h3': True, 'h3': 48, 'dropout': 0.1, 'lr': 0.0011824418109049777, 'weight_decay': 4.9685812339292976e-05, 'batch': 128}

# %%
# ── Métricas finales en escala original ──────
with torch.no_grad():
    best_model.eval()
    preds_te_std = best_model(torch.from_numpy(X_te).to(device)).cpu().numpy()
    preds_tr_std = best_model(torch.from_numpy(X_tr).to(device)).cpu().numpy()

y_te_inv  = sc_y.inverse_transform(y_te)
y_tr_inv  = sc_y.inverse_transform(y_tr)
preds_te  = sc_y.inverse_transform(preds_te_std)
preds_tr  = sc_y.inverse_transform(preds_tr_std)

print("R² test :", r2_score(y_te_inv, preds_te))
print("RMSE test:", mean_squared_error(y_te_inv, preds_te, squared=False))
print("R² train:", r2_score(y_tr_inv, preds_tr))
print("RMSE train:", mean_squared_error(y_tr_inv, preds_tr, squared=False))
# Out:
# R² test : 0.6319578886032104
# RMSE test: 41.62209
# R² train: 0.7274125814437866
# RMSE train: 36.187042

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Predictions")
plt.scatter(y_tr_inv,preds_tr,label="Train")
plt.scatter(y_te_inv,preds_te,label="Test")
plt.legend()
plt.subplot(122)
plt.title("Resisuals")
plt.scatter(y_tr_inv,preds_tr-y_tr_inv,label="Train")
plt.scatter(y_te_inv,preds_te-y_te_inv,label="Test")
plt.legend()
plt.show()

# %% [markdown]
# # 3 | XGBoost GPU

# %%
import xgboost as xgb
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
import optuna, numpy as np

dtrain, dtest = xgb.DMatrix(X_tr, label=y_tr), xgb.DMatrix(X_te, label=y_te)

# ── ¿XGBoost tiene GPU? ───────────────────────────────
def xgb_gpu_available() -> bool:
    try:
        # Desde XGB 2.0 existe esto:
        return xgb.core._has_cuda_support()
    except AttributeError:
        # Fallback: intenta una llamada dummy
        try:
            xgb.train({'tree_method':'gpu_hist'}, dtrain, num_boost_round=1, verbose_eval=False)
            return True
        except xgb.core.XGBoostError:
            return False

USE_GPU = xgb_gpu_available()
print("XGBoost GPU disponible?:", USE_GPU)

tree_method = 'gpu_hist' if USE_GPU else 'hist'

# ── Optuna objective ──────────────────────────────────

def objective(trial):
    param = {
        "objective": "reg:squarederror",
        "tree_method": tree_method,          # 'gpu_hist' o 'hist'
        "learning_rate": trial.suggest_float("eta", 0.02, 0.15, log=True),
        "max_depth": trial.suggest_int("max_depth", 1, 4),
        "subsample": trial.suggest_float("subsample", 0.5, 0.9),
        "colsample_bytree": trial.suggest_float("colsample", 0.4, 0.9),
        "lambda": trial.suggest_float("lambda", 1.0, 10.0, log=True),
        "alpha": trial.suggest_float("alpha", 0.0, 1.0),
        "min_child_weight": trial.suggest_float("min_child_weight", 5, 10, log=True),
    }
    n_rounds = trial.suggest_int("n_rounds", 500, 3000, step=500)

    booster = xgb.train(
        param,
        dtrain,
        num_boost_round=n_rounds,
        evals=[(dtest, "val")],
        verbose_eval=False,
        early_stopping_rounds=50,
    )
    preds = booster.predict(dtest)
    return mean_squared_error(y_te, preds)          # Optuna minimiza

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=50, show_progress_bar=True, timeout=None)

best_params = study.best_params | {
    "objective": "reg:squarederror",
    "tree_method": tree_method
}
best_rounds = best_params.pop("n_rounds")
booster = xgb.train(best_params, dtrain,
                    num_boost_round=best_rounds,
                    evals=[(dtest, "val")],
                    early_stopping_rounds=50,
                    verbose_eval=False)
# Out:
# [I 2025-07-11 08:23:58,364] A new study created in memory with name: no-name-2989caf0-a48a-4e7d-98be-36d92f7ebca6
# XGBoost GPU disponible?: False
# Best trial: 0. Best value: 0.0250325:   2%|▏         | 1/50 [00:01<00:50,  1.04s/it]
# [I 2025-07-11 08:23:59,401] Trial 0 finished with value: 0.02503245696425438 and parameters: {'eta': 0.1289691275144949, 'max_depth': 3, 'subsample': 0.6145959447341715, 'colsample': 0.4567253710245668, 'lambda': 2.737396264905989, 'alpha': 0.3976872382151595, 'min_child_weight': 8.542731458331787, 'n_rounds': 2500}. Best is trial 0 with value: 0.02503245696425438.
# Best trial: 0. Best value: 0.0250325:   4%|▍         | 2/50 [00:01<00:29,  1.62it/s]
# [I 2025-07-11 08:23:59,720] Trial 1 finished with value: 0.029555369168519974 and parameters: {'eta': 0.060484714921722804, 'max_depth': 2, 'subsample': 0.6584502825722698, 'colsample': 0.5237477031727189, 'lambda': 8.283077453092073, 'alpha': 0.3340847034865315, 'min_child_weight': 6.2205161428022, 'n_rounds': 500}. Best is trial 0 with value: 0.02503245696425438.
# Best trial: 0. Best value: 0.0250325:   6%|▌         | 3/50 [00:01<00:29,  1.61it/s]
# [I 2025-07-11 08:24:00,350] Trial 2 finished with value: 0.029543017968535423 and parameters: {'eta': 0.031724730863742945, 'max_depth': 2, 'subsample': 0.7460180071537222, 'colsample': 0.4437209144651049, 'lambda': 1.1176377157650688, 'alpha': 0.7239027046001627, 'min_child_weight': 7.018716090374891, 'n_rounds': 1000}. Best is trial 0 with value: 0.02503245696425438.
# Best trial: 0. Best value: 0.0250325:   8%|▊         | 4/50 [00:02<00:23,  1.94it/s]
# [I 2025-07-11 08:24:00,700] Trial 3 finished with value: 0.02906707488000393 and parameters: {'eta': 0.06759396925660519, 'max_depth': 2, 'subsample': 0.6835562913736989, 'colsample': 0.8808624080718443, 'lambda': 1.1452324618541108, 'alpha': 0.847007498118543, 'min_child_weight': 8.506248766419965, 'n_rounds': 500}. Best is trial 0 with value: 0.02503245696425438.
# Best trial: 40. Best value: 0.0214659:  86%|████████▌ | 43/50 [01:18<00:12,  1.83s/it]
# [I 2025-07-11 08:25:16,444] Trial 42 finished with value: 0.02221144177019596 and parameters: {'eta': 0.09812009420219617, 'max_depth': 4, 'subsample': 0.6958643363991233, 'colsample': 0.744721304217286, 'lambda': 3.103843942771386, 'alpha': 0.44025133075974276, 'min_child_weight': 7.150117743119044, 'n_rounds': 1500}. Best is trial 40 with value: 0.021465880796313286.
# Best trial: 43. Best value: 0.0213907:  88%|████████▊ | 44/50 [01:20<00:12,  2.06s/it]
# [I 2025-07-11 08:25:19,036] Trial 43 finished with value: 0.021390721201896667 and parameters: {'eta': 0.12698889099673313, 'max_depth': 4, 'subsample': 0.7532714945306778, 'colsample': 0.7147829660930083, 'lambda': 2.1770184256920637, 'alpha': 0.2539268085793034, 'min_child_weight': 6.138928042376396, 'n_rounds': 2500}. Best is trial 43 with value: 0.021390721201896667.
# Best trial: 43. Best value: 0.0213907:  90%|█████████ | 45/50 [01:22<00:09,  1.91s/it]
# [I 2025-07-11 08:25:20,590] Trial 44 finished with value: 0.02191445231437683 and parameters: {'eta': 0.1265644555728068, 'max_depth': 4, 'subsample': 0.7509105636209099, 'colsample': 0.7183729204674186, 'lambda': 1.5339189710848535, 'alpha': 0.24594544397991092, 'min_child_weight': 5.685613560855193, 'n_rounds': 1500}. Best is trial 43 with value: 0.021390721201896667.
# Best trial: 45. Best value: 0.0212977:  92%|█████████▏| 46/50 [01:24<00:07,  1.98s/it]
# [I 2025-07-11 08:25:22,731] Trial 45 finished with value: 0.02129773423075676 and parameters: {'eta': 0.1226716736920629, 'max_depth': 4, 'subsample': 0.7130788655115698, 'colsample': 0.8445256577787641, 'lambda': 2.1538075202117852, 'alpha': 0.18273441793733503, 'min_child_weight': 6.031658451885037, 'n_rounds': 2000}. Best is trial 45 with value: 0.02129773423075676.
# Best trial: 45. Best value: 0.0212977:  94%|█████████▍| 47/50 [01:26<00:05,  1.94s/it]
# [I 2025-07-11 08:25:24,594] Trial 46 finished with value: 0.02162966877222061 and parameters: {'eta': 0.11242044927222954, 'max_depth': 4, 'subsample': 0.7154396568171943, 'colsample': 0.8183674507529699, 'lambda': 1.7394627538469318, 'alpha': 0.0717124276451954, 'min_child_weight': 6.083170050500046, 'n_rounds': 2500}. Best is trial 45 with value: 0.02129773423075676.
# Best trial: 45. Best value: 0.0212977:  96%|█████████▌| 48/50 [01:26<00:03,  1.54s/it]
# [I 2025-07-11 08:25:25,189] Trial 47 finished with value: 0.03079180046916008 and parameters: {'eta': 0.11383286939758952, 'max_depth': 1, 'subsample': 0.7302733497996675, 'colsample': 0.8319119180901267, 'lambda': 1.0952254328762463, 'alpha': 0.06866916995564398, 'min_child_weight': 6.204044627900711, 'n_rounds': 3000}. Best is trial 45 with value: 0.02129773423075676.
# Best trial: 45. Best value: 0.0212977:  98%|█████████▊| 49/50 [01:27<00:01,  1.40s/it]
# [I 2025-07-11 08:25:26,264] Trial 48 finished with value: 0.021997055038809776 and parameters: {'eta': 0.13242191794254893, 'max_depth': 4, 'subsample': 0.7573469487946525, 'colsample': 0.8626085572822879, 'lambda': 1.6831390514406352, 'alpha': 0.07825059342628193, 'min_child_weight': 6.898370078468185, 'n_rounds': 1000}. Best is trial 45 with value: 0.02129773423075676.
# Best trial: 45. Best value: 0.0212977: 100%|██████████| 50/50 [01:29<00:00,  1.78s/it]
# [I 2025-07-11 08:25:27,572] Trial 49 finished with value: 0.022260816767811775 and parameters: {'eta': 0.11414129217700324, 'max_depth': 4, 'subsample': 0.7111045780319798, 'colsample': 0.7997740083846808, 'lambda': 2.20816004957374, 'alpha': 0.858724656736064, 'min_child_weight': 7.9866802102850984, 'n_rounds': 2500}. Best is trial 45 with value: 0.02129773423075676.

# %%
preds_te_std2 = booster.predict(dtest)
preds_tr_std2 = booster.predict(dtrain)

y_te_inv2  = sc_y.inverse_transform(y_te)
y_tr_inv2  = sc_y.inverse_transform(y_tr)
preds_te2  = sc_y.inverse_transform(np.array(preds_te_std2).reshape(-1, 1))
preds_tr2  = sc_y.inverse_transform(np.array(preds_tr_std2).reshape(-1, 1))

print("R² test :", r2_score(y_te_inv2, preds_te2))
print("RMSE test:", mean_squared_error(y_te_inv2, preds_te2, squared=False))
print("R² train:", r2_score(y_tr_inv2, preds_tr2))
print("RMSE train:", mean_squared_error(y_tr_inv2, preds_tr2, squared=False))
# Out:
# R² test : 0.6615542769432068
# RMSE test: 39.913486
# R² train: 0.9393815398216248
# RMSE train: 17.06486

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Predictions")
plt.scatter(y_tr_inv2,preds_tr2,label="Train")
plt.scatter(y_te_inv2,preds_te2,label="Test")
plt.legend()
plt.subplot(122)
plt.title("Resisuals")
plt.scatter(y_tr_inv2,preds_tr2-y_tr_inv2,label="Train")
plt.scatter(y_te_inv2,preds_te2-y_te_inv2,label="Test")
plt.legend()
plt.show()

# %%
booster

# %%
import numpy as np, matplotlib.pyplot as plt, xgboost as xgb, torch
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from typing import Any

# ═══════════════════════════════════════════════════════════════════
# 1. Wrappers: dan predict() y un fit() vacío (requisito sklearn)
# ═══════════════════════════════════════════════════════════════════
class TorchRegressorWrapper:
    def __init__(self, model: torch.nn.Module, scaler_y):
        self.model = model.eval().to(next(model.parameters()).device)
        self.scaler_y = scaler_y
    def fit(self, X: Any, y: Any):     # <- para que sklearn no proteste
        return self
    def predict(self, X):
        X_t = torch.tensor(X, dtype=torch.float32, device=next(self.model.parameters()).device)
        with torch.no_grad():
            y_hat_std = self.model(X_t).cpu().numpy()
        return self.scaler_y.inverse_transform(y_hat_std).ravel()

class XGBRegressorWrapper:
    def __init__(self, booster: xgb.Booster):
        self.bst = booster
    def fit(self, X: Any, y: Any):
        return self
    def predict(self, X):
        return self.bst.predict(xgb.DMatrix(X))

mlp_wrap = TorchRegressorWrapper(best_model, sc_y)
xgb_wrap = XGBRegressorWrapper(booster)

# ═══════════════════════════════════════════════════════════════════
# 2. Conjuntos para permutar
#    · MLP → entradas estandarizadas
#    · XGB → sin escalar
# ═══════════════════════════════════════════════════════════════════
X_te_std = sc_x.transform(X_te)        # estándar usado en entrenamiento MLP

# ═══════════════════════════════════════════════════════════════════
# 3. Permutation Feature Importance
# ═══════════════════════════════════════════════════════════════════
def pfi(estimator, X, y):
    return permutation_importance(
        estimator, X, y,
        n_repeats=50,
        scoring="neg_root_mean_squared_error",
        random_state=rs,
        n_jobs=-1)

pi_mlp = pfi(mlp_wrap, X_te, y_te)
pi_xgb = pfi(xgb_wrap, X_te, y_te)

# %%
feat_names = data.drop(columns=[var]).columns
len(feat_names)
# Out:
# 15

# %%
sumi=pd.DataFrame({"Features":feat_names,
                   "Importances Mean (MLP)":pi_mlp.importances_mean, 
                   "Importances Std (MLP)":pi_mlp.importances_std,
                  "Importances Mean (XB)":pi_xgb.importances_mean, 
                   "Importances Std (XB)":pi_xgb.importances_std})

# %%
# ═══════════════════════════════════════════════════════════════════
# 4. Plot boxplots lado a lado
# ═══════════════════════════════════════════════════════════════════
def plot_box(ax, result, title):
    order = np.argsort(result.importances_mean)[::-1]
    ax.boxplot(result.importances.T[:, order], vert=False,
               labels=feat_names[order])
    ax.axvline(0, color="k", ls="--")
    ax.set_title(title)
    ax.set_xlabel("Decrease in RMSE (perm−base)")

fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharex=False, sharey=False)
plot_box(axes[0], pi_mlp, "Permutation Importance – MLP")
plot_box(axes[1], pi_xgb, "Permutation Importance – XGBoost")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Permutation Importance – MLP")
plt.boxplot(pi_mlp.importances.T[:, np.argsort(pi_mlp.importances_mean)[::-1]]*1, vert=False,
               labels=feat_names[np.argsort(pi_mlp.importances_mean)[::-1]], medianprops=dict(color='red'), 
            patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.axvline(0, color="k", ls="--"); plt.grid(alpha=0.3)
plt.subplot(122)
plt.title("Permutation Importance – XGBoost")
plt.boxplot(np.log10(pi_xgb.importances.T[:, np.argsort(pi_xgb.importances_mean)[::-1]]*150), vert=False,
               labels=feat_names[np.argsort(pi_xgb.importances_mean)[::-1]], medianprops=dict(color='red'), 
            patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.axvline(0, color="k", ls="--"); plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("figures/FeatureImportanceR_local.pdf",bbox_inches='tight',dpi=300)
plt.show()

# %%
data[var].plot(figsize=(14,2)); plt.legend(); plt.grid(alpha=0.3)
data[var].ewm(alpha=0.01).mean().plot(figsize=(14,2),c="k",label="R smooth"); plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.savefig("figures/R_local.pdf",bbox_inches='tight',dpi=300)
plt.show()

# %%
data["Lempel-Ziv Complexity"].plot(figsize=(14,2)); plt.legend(); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.savefig("figures/LZ_R_local.pdf",bbox_inches='tight',dpi=300)
plt.show()

# %%
data["Petrosian Fractal Dim."].plot(figsize=(14,2)); plt.legend(); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.savefig("figures/Petro_R_local.pdf",bbox_inches='tight',dpi=300)
plt.show()

# %%
data["Permutation Entropy"].plot(figsize=(14,2)); plt.legend(); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.savefig("figures/Permutation_R_local.pdf",bbox_inches='tight',dpi=300)
plt.show()

# %%
data["Spectral Entropy"].plot(figsize=(14,2)); plt.legend(); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.savefig("figures/Spectral_R_local.pdf",bbox_inches='tight',dpi=300)
plt.show()

# %%
data["Shannon Entropy"].plot(figsize=(14,2)); plt.legend(); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.savefig("figures/Shannon_R_local.pdf",bbox_inches='tight',dpi=300)
plt.show()

# %%
data["Katz Fractal Dim."].plot(figsize=(14,2)); plt.legend(); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.savefig("figures/Katz_R_local.pdf",bbox_inches='tight',dpi=300)
plt.show()

# %%
data["Higuchi Fractal Dim."].plot(figsize=(14,2)); plt.legend(); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.savefig("figures/higuchi_R_local.pdf",bbox_inches='tight',dpi=300)
plt.show()

# %% [markdown]
# All figures in one...

# %%
plt.subplots(8,1,sharex=True,figsize=(14,12))
plt.subplot(811)
data[var].plot(); plt.legend(); plt.grid(alpha=0.3); 
data[var].ewm(alpha=0.01).mean().plot(c="k",label="F10.7 smooth"); plt.legend(ncol=2,loc=2); plt.grid(alpha=0.3)
plt.subplot(812)
data["Lempel-Ziv Complexity"].plot(); plt.legend(loc=2); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.subplot(813)
data["Sample Entropy"].plot(); plt.legend(loc=2); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.subplot(814)
data["Higuchi Fractal Dim."].plot(); plt.legend(loc=2); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.subplot(815)
data["Permutation Entropy"].plot(); plt.legend(loc=2); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.subplot(816)
data["Spectral Entropy"].plot(); plt.legend(loc=2); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.subplot(817)
data["Petrosian Fractal Dim."].plot(); plt.legend(loc=2); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.subplot(818)
data["Shannon Entropy"].plot(); plt.legend(loc=2); plt.grid(alpha=0.3)
plt.legend(ncol=2); plt.grid(alpha=0.3)
plt.tight_layout(h_pad=-0.2)
plt.savefig("figures/All_R_local.pdf",bbox_inches='tight',dpi=300)
plt.show()
